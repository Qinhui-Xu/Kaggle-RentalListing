# %%
import numpy as np # linear algebra
import json
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
pd.options.mode.chained_assignment = None  # default='warn'
from scipy import sparse
import xgboost as xgb
import random
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import log_loss
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
with open('/Users/apple1/desktop/kaggle/RentalListing/train.json') as data_file:    
    train_df = pd.read_json(data_file)
with open('/Users/apple1/desktop/kaggle/RentalListing/test.json') as data_file:    
    test_df = pd.read_json(data_file)

# %%
import math
def cart2rho(x, y):
    rho = np.sqrt(x**2 + y**2)
    return rho


def cart2phi(x, y):
    phi = np.arctan2(y, x)
    return phi


def rotation_x(row, alpha):
    x = row['latitude']
    y = row['longitude']
    return x*math.cos(alpha) + y*math.sin(alpha)


def rotation_y(row, alpha):
    x = row['latitude']
    y = row['longitude']
    return y*math.cos(alpha) - x*math.sin(alpha)


def add_rotation(degrees, df):
    namex = "rot" + str(degrees) + "_X"
    namey = "rot" + str(degrees) + "_Y"

    df['num_' + namex] = df.apply(lambda row: rotation_x(row, math.pi/(180/degrees)), axis=1)
    df['num_' + namey] = df.apply(lambda row: rotation_y(row, math.pi/(180/degrees)), axis=1)

    return df

def operate_on_coordinates(tr_df, te_df):
    for df in [tr_df, te_df]:
        #polar coordinates system
        df["num_rho"] = df.apply(lambda x: cart2rho(x["latitude"] - 40.78222222, x["longitude"]+73.96527777), axis=1)
        df["num_phi"] = df.apply(lambda x: cart2phi(x["latitude"] - 40.78222222, x["longitude"]+73.96527777), axis=1)
        #rotations
        for angle in [15,30,45,60]:
            df = add_rotation(angle, df)

    return tr_df, te_df

train_df, test_df = operate_on_coordinates(train_df, test_df)

# %%
import re

def cap_share(x):
    return sum(1 for c in x if c.isupper())/float(len(x)+1)

for df in [train_df, test_df]:
    # do you think that users might feel annoyed BY A DESCRIPTION THAT IS SHOUTING AT THEM?
    df['num_cap_share'] = df['description'].apply(cap_share)
    
    # how long in lines the desc is?
    df['num_nr_of_lines'] = df['description'].apply(lambda x: x.count('<br /><br />'))
   
    # is the description redacted by the website?        
    df['num_redacted'] = 0
    df['num_redacted'].ix[df['description'].str.contains('website_redacted')] = 1

    
    # can we contact someone via e-mail to ask for the details?
    df['num_email'] = 0
    df['num_email'].ix[df['description'].str.contains('@')] = 1
    
    #and... can we call them?
    
    reg = re.compile(".*?(\(?\d{3}\D{0,3}\d{3}\D{0,3}\d{4}).*?", re.S)
    def try_and_find_nr(description):
        if reg.match(description) is None:
            return 0
        return 1

    df['num_phone_nr'] = df['description'].apply(try_and_find_nr)

# %%
list(train_df)
# Out:
# ['bathrooms',
#  'bedrooms',
#  'building_id',
#  'created',
#  'description',
#  'display_address',
#  'features',
#  'interest_level',
#  'latitude',
#  'listing_id',
#  'longitude',
#  'manager_id',
#  'photos',
#  'price',
#  'street_address',
#  'num_rho',
#  'num_phi',
#  'num_rot15_X',
#  'num_rot15_Y',
#  'num_rot30_X',
#  'num_rot30_Y',
#  'num_rot45_X',
#  'num_rot45_Y',
#  'num_rot60_X',
#  'num_rot60_Y',
#  'num_cap_share',
#  'num_nr_of_lines',
#  'num_redacted',
#  'num_email',
#  'num_phone_nr']

# %%
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=321, num_rounds=1800):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.021
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=20)
    else:
        xgtest = xgb.DMatrix(test_X)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
test_df["bathrooms"].loc[19671] = 1.5
test_df["bathrooms"].loc[22977] = 2.0
test_df["bathrooms"].loc[63719] = 2.0
train_df["price"] = train_df["price"].clip(upper=13000)

# %%
train_df["logprice"] = np.log(train_df["price"])
test_df["logprice"] = np.log(test_df["price"])

# %%
train_df['half_bathrooms'] = train_df["bathrooms"] - train_df["bathrooms"].apply(int)#.astype(int) # Half bathrooms? 1.5, 2.5, 3.5...
test_df['half_bathrooms'] = test_df["bathrooms"] - test_df["bathrooms"].apply(int)#.astype(int) # Half bathrooms?

# %%
train_df["price_t"] =train_df["price"]/train_df["bedrooms"]
test_df["price_t"] = test_df["price"]/test_df["bedrooms"] 

train_df["room_sum"] = train_df["bedrooms"]+train_df["bathrooms"] 
test_df["room_sum"] = test_df["bedrooms"]+test_df["bathrooms"] 

train_df['price_per_room'] = train_df['price']/train_df['room_sum']
test_df['price_per_room'] = test_df['price']/test_df['room_sum']

train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour

#train_df["created_weekday"] = train_df["created"].dt.weekday
#test_df["created_weekday"] = test_df["created"].dt.weekday
#train_df["created_week"] = train_df["created"].dt.week
#test_df["created_week"] = test_df["created"].dt.week

train_df["pos"] = train_df.longitude.round(3).astype(str) + '_' + train_df.latitude.round(3).astype(str)
test_df["pos"] = test_df.longitude.round(3).astype(str) + '_' + test_df.latitude.round(3).astype(str)

vals = train_df['pos'].value_counts()
dvals = vals.to_dict()
train_df["density"] = train_df['pos'].apply(lambda x: dvals.get(x, vals.min()))
test_df["density"] = test_df['pos'].apply(lambda x: dvals.get(x, vals.min()))

# %%
#train_df["bedBathDiff"] = train_df['bedrooms'] - train_df['bathrooms']
#test_df["bedBathDiff"] = test_df['bedrooms'] - test_df['bathrooms']

#train_df["bedsPerc"] = train_df["bedrooms"] / train_df["room_sum"]
#test_df["bedsPerc"] = test_df["bedrooms"] / test_df["room_sum"]

# %%
#bedroom*bathroom
train_df["bed_bath"] = train_df["bedrooms"]*train_df["bathrooms"]
test_df["bed_bath"] = test_df["bedrooms"]*test_df["bathrooms"]

#bedroom*price
train_df["bed_price"] = train_df["bedrooms"]*train_df["price"]
test_df["bed_price"] = test_df["bedrooms"]*test_df["price"]

#bathroom*price
train_df["bath_price"] = train_df["bathrooms"]*train_df["price"]
test_df["bath_price"] = test_df["bathrooms"]*test_df["price"]

#bathroom*photos
train_df["bath_photo"] = train_df["bathrooms"]*train_df["num_photos"]
test_df["bath_photo"] = test_df["bathrooms"]*test_df["num_photos"]

#bedroom*photos
train_df["bed_photo"] = train_df["bedrooms"]*train_df["num_photos"]
test_df["bed_photo"] = test_df["bedrooms"]*test_df["num_photos"]

#price*photos
train_df["price_photo"] = train_df["price"]*train_df["num_photos"]
test_df["price_photo"] = test_df["price"]*test_df["num_photos"]

#price*features
train_df["price_feat"] = train_df["price"]*train_df["num_features"]
test_df["price_feat"] = test_df["price"]*test_df["num_features"]

#bed*features
train_df["bed_feat"] = train_df["bedrooms"]*train_df["num_features"]
test_df["bed_feat"] = test_df["bedrooms"]*test_df["num_features"]

#bath*features
train_df["bath_feat"] = train_df["bathrooms"]*train_df["num_features"]
test_df["bath_feat"] = test_df["bathrooms"]*test_df["num_features"]

#bed*features
train_df["bed_desc"] = train_df["bedrooms"]*train_df["num_description_words"]
test_df["bed_desc"] = test_df["bedrooms"]*test_df["num_description_words"]

#bath*features
train_df["bath_desc"] = train_df["bathrooms"]*train_df["num_description_words"]
test_df["bath_desc"] = test_df["bathrooms"]*test_df["num_description_words"]

#price*features
train_df["price_desc"] = train_df["price"]*train_df["num_description_words"]
test_df["price_desc"] = test_df["price"]*test_df["num_description_words"]

# %%
train_df["listing_id2"] = train_df["listing_id"] - 68119576.0
test_df["listing_id2"] =  test_df["listing_id"] - 68119576.0

train_df["total_days"] =   (train_df["created_month"] -4.0)*30 + train_df["created_day"] +  train_df["created_hour"] /25.0
test_df["total_days"] =(test_df["created_month"] -4.0)*30 + test_df["created_day"] +  test_df["created_hour"] /25.0        
train_df["diff_rank"]= train_df["total_days"]/train_df["listing_id2"]
test_df["diff_rank"]= test_df["total_days"]/test_df["listing_id2"]

# %%
image_date = pd.read_csv("/Users/apple1/desktop/kaggle/RentalListing/listing_image_time.csv")

# rename columns so you can join tables later on
image_date.columns = ["listing_id", "time_stamp"]

# reassign the only one timestamp from April, all others from Oct/Nov
image_date.loc[80240,"time_stamp"] = 1478129766 

image_date["img_date"]                  = pd.to_datetime(image_date["time_stamp"], unit="s")
image_date["img_days_passed"]           = (image_date["img_date"].max() - image_date["img_date"]).astype("timedelta64[D]").astype(int)
image_date["img_date_month"]            = image_date["img_date"].dt.month
image_date["img_date_week"]             = image_date["img_date"].dt.week
image_date["img_date_day"]              = image_date["img_date"].dt.day
image_date["img_date_dayofweek"]        = image_date["img_date"].dt.dayofweek
image_date["img_date_dayofyear"]        = image_date["img_date"].dt.dayofyear
image_date["img_date_hour"]             = image_date["img_date"].dt.hour
image_date["img_date_monthBeginMidEnd"] = image_date["img_date_day"].apply(lambda x: 1 if x<10 else 2 if x<20 else 3)

train_df = pd.merge(train_df, image_date, on="listing_id", how="left")
test_df = pd.merge(test_df, image_date, on="listing_id", how="left")

# %%
features_to_use=["bathrooms", "bedrooms", "latitude", "longitude", "price","price_t","price_per_room", "logprice", "density", "half_bathrooms",
"num_photos", "num_features", "num_description_words","listing_id", "created_year", "created_month", "created_day", "created_hour",#"bedBathDiff","bedsPerc",
"img_days_passed","img_date_month","img_date_week","img_date_day","img_date_dayofweek","img_date_dayofyear",
"img_date_hour","img_date_monthBeginMidEnd","bed_bath","bed_price","bath_price","bed_photo","price_photo","price_feat","bed_feat","bath_feat",
"bath_desc","price_desc","total_days","diff_rank","num_rho","num_phi","num_rot15_X", 'num_rot15_Y','num_rot30_X','num_rot30_Y',
'num_rot45_X','num_rot45_Y','num_rot60_X','num_rot60_Y','num_cap_share','num_nr_of_lines','num_redacted','num_email','num_phone_nr']

# %%
index=list(range(train_df.shape[0]))
random.shuffle(index)
a=[np.nan]*len(train_df)
b=[np.nan]*len(train_df)
c=[np.nan]*len(train_df)

# %%
for i in range(5):
    building_level={}
    for j in train_df['manager_id'].values:
        building_level[j]=[0,0,0]
    
    test_index=index[int((i*train_df.shape[0])/5):int(((i+1)*train_df.shape[0])/5)]
    train_index=list(set(index).difference(test_index))
    
    for j in train_index:
        temp=train_df.iloc[j]
        if temp['interest_level']=='low':
            building_level[temp['manager_id']][0]+=1
        if temp['interest_level']=='medium':
            building_level[temp['manager_id']][1]+=1
        if temp['interest_level']=='high':
            building_level[temp['manager_id']][2]+=1
            
    for j in test_index:
        temp=train_df.iloc[j]
        if sum(building_level[temp['manager_id']])!=0:
            a[j]=building_level[temp['manager_id']][0]*1.0/sum(building_level[temp['manager_id']])
            b[j]=building_level[temp['manager_id']][1]*1.0/sum(building_level[temp['manager_id']])
            c[j]=building_level[temp['manager_id']][2]*1.0/sum(building_level[temp['manager_id']])

# %%
train_df['manager_level_low']=a
train_df['manager_level_medium']=b
train_df['manager_level_high']=c

# %%
a=[]
b=[]
c=[]
building_level={}
for j in train_df['manager_id'].values:
    building_level[j]=[0,0,0]

for j in range(train_df.shape[0]):
    temp=train_df.iloc[j]
    if temp['interest_level']=='low':
        building_level[temp['manager_id']][0]+=1
    if temp['interest_level']=='medium':
        building_level[temp['manager_id']][1]+=1
    if temp['interest_level']=='high':
        building_level[temp['manager_id']][2]+=1

for i in test_df['manager_id'].values:
    if i not in building_level.keys():
        a.append(np.nan)
        b.append(np.nan)
        c.append(np.nan)
    else:
        a.append(building_level[i][0]*1.0/sum(building_level[i]))
        b.append(building_level[i][1]*1.0/sum(building_level[i]))
        c.append(building_level[i][2]*1.0/sum(building_level[i]))
test_df['manager_level_low']=a
test_df['manager_level_medium']=b
test_df['manager_level_high']=c

# %%
features_to_use.append('manager_level_low') 
features_to_use.append('manager_level_medium') 
features_to_use.append('manager_level_high')

# %%
categorical = ["street_address", "display_address", "manager_id", "building_id"]
for f in categorical:
        if train_df[f].dtype=='object':
            lbl = LabelEncoder()
            lbl.fit(list(train_df[f].values) + list(test_df[f].values))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)

# %%
with open('/Users/apple1/desktop/kaggle/RentalListing/train.json') as data_file:    
    train_df2 = pd.read_json(data_file)
with open('/Users/apple1/desktop/kaggle/RentalListing/test.json') as data_file:    
    test_df2 = pd.read_json(data_file)
train_df2['features'] = train_df2["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
test_df2['features'] = test_df2["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import sent_tokenize

def description_sentiment(sentences):
    analyzer = SentimentIntensityAnalyzer()
    result = []
    for sentence in sentences:
        vs = analyzer.polarity_scores(sentence)
        result.append(vs)
    return pd.DataFrame(result).mean()

# %%
sdf = train_df
sdf['description_tokens'] = sdf['description'].apply(sent_tokenize)
sdf = pd.concat([sdf,sdf['description_tokens'].apply(description_sentiment)],axis=1)

# %%
sdf_test = test_df
sdf_test['description_tokens'] = sdf_test['description'].apply(sent_tokenize)
sdf_test = pd.concat([sdf_test,sdf_test['description_tokens'].apply(description_sentiment)],axis=1)

# %%
#sdf['pos']= np.log(sdf['pos'])
#sdf_test['pos']= np.log(sdf_test['pos'])
#sdf['neg']= np.log(sdf['neg'])
#sdf_test['neg']= np.log(sdf_test['neg'])
#sdf['compound']= np.log(sdf['compound'])
#sdf_test['compound']= np.log(sdf_test['compound'])
#sdf['neu']= np.log(sdf['neu'])
#sdf_test['neu']= np.log(sdf_test['neu'])

train_df = sdf
test_df = sdf_test
features_to_use.append("compound")
features_to_use.append("neu")
features_to_use.append("neg")
#features_to_use.append("pos")

# %%
bows = { "dogs": ("dogs", "dog"), "cats": ("cats","cat"), "nofee": ("no fee", "no-fee", "no fee", "nofee", "no_fee"), "lowfee": ("reduced_fee", "low_fee", "reduced fee", "low fee"), "exclusive": ("Exclusive"), "parquet": ("parquet", "hardwood"), "concierge": ("concierge", "doorman", "housekeep", "in_super"), "prewar": ("prewar", "pre_war", "pre war", "pre-war"), "laundry": ("laundry", "lndry" ,"Laundry in Unit"), "health": ("health", "gym", "fitness", "training"), "transport": ("train", "subway", "transport"), "parking": ("parking",), "utilities": ("utilities", "heat water", "water included" ,"Dishwasher"), "elevator":("Elevator") }

# %%
bows
# Out:
# {'cats': ('cats', 'cat'),
#  'concierge': ('concierge', 'doorman', 'housekeep', 'in_super'),
#  'dogs': ('dogs', 'dog'),
#  'elevator': 'Elevator',
#  'exclusive': 'Exclusive',
#  'health': ('health', 'gym', 'fitness', 'training'),
#  'laundry': ('laundry', 'lndry', 'Laundry in Unit'),
#  'lowfee': ('reduced_fee', 'low_fee', 'reduced fee', 'low fee'),
#  'nofee': ('no fee', 'no-fee', 'no fee', 'nofee', 'no_fee'),
#  'parking': ('parking',),
#  'parquet': ('parquet', 'hardwood'),
#  'prewar': ('prewar', 'pre_war', 'pre war', 'pre-war'),
#  'transport': ('train', 'subway', 'transport'),
#  'utilities': ('utilities', 'heat water', 'water included', 'Dishwasher')}

# %%
train_df["features"][1]
# Out:
# ['Doorman', 'Elevator', 'Fitness Center', 'Cats Allowed', 'Dogs Allowed']

# %%
train_df.shape[0]
# Out:
# 49352

# %%
for i in range(3):
    for feat in train_df["features"][i]:
        print(feat)
# Out:
# Doorman
# Elevator
# Fitness Center
# Cats Allowed
# Dogs Allowed
# Laundry In Building
# Dishwasher
# Hardwood Floors
# Pets Allowed Case by Case

# %%
bows
# Out:
# {'cats': ('cats', 'cat'),
#  'concierge': ('concierge', 'doorman', 'housekeep', 'in_super'),
#  'dogs': ('dogs', 'dog'),
#  'elevator': 'Elevator',
#  'exclusive': 'Exclusive',
#  'health': ('health', 'gym', 'fitness', 'training'),
#  'laundry': ('laundry', 'lndry', 'Laundry in Unit'),
#  'lowfee': ('reduced_fee', 'low_fee', 'reduced fee', 'low fee'),
#  'nofee': ('no fee', 'no-fee', 'no fee', 'nofee', 'no_fee'),
#  'parking': ('parking',),
#  'parquet': ('parquet', 'hardwood'),
#  'prewar': ('prewar', 'pre_war', 'pre war', 'pre-war'),
#  'transport': ('train', 'subway', 'transport'),
#  'utilities': ('utilities', 'heat water', 'water included', 'Dishwasher')}

# %%
bows['cats']
# Out:
# ('cats', 'cat')

# %%
train_df["cats"]=0
train_df["concierge"]=0
train_df["dogs"]=0
train_df["elevator"]=0
train_df["health"]=0
train_df["laundry"]=0
train_df["lowfee"]=0
train_df["nofee"]=0
train_df["parking"]=0
train_df["parquet"]=0
train_df["prewar"]=0
train_df["transport"]=0
train_df["utilities"]=0

# %%
for i in range(train_df.shape[0]):
    for feat in train_df["features"][i]:
        if feat in bows['cats']:
            train_df["cats"][i]=1
        if feat in bows["concierge"]:
            train_df["concierge"]=1
        if feat in bows['dogs']:
            train_df["dogs"][i]=1
        if feat in bows["elevator"]:
            train_df["elevator"]=1
        if feat in bows['health']:
            train_df["health"][i]=1
        if feat in bows["laundry"]:
            train_df["laundry"]=1
        if feat in bows['lowfee']:
            train_df["lowfee"][i]=1
        if feat in bows["nofee"]:
            train_df["nofee"]=1
        if feat in bows['parking']:
            train_df["parking"][i]=1
        if feat in bows["parquet"]:
            train_df["parquet"]=1
        if feat in bows['prewar']:
            train_df["prewar"][i]=1
        if feat in bows["transport"]:
            train_df["transport"]=1
        if feat in bows["utilities"]:
            train_df["utilities"]=1

# %%
test_df["cats"]=0
test_df["concierge"]=0
test_df["dogs"]=0
test_df["elevator"]=0
test_df["health"]=0
test_df["laundry"]=0
test_df["lowfee"]=0
test_df["nofee"]=0
test_df["parking"]=0
test_df["parquet"]=0
test_df["prewar"]=0
test_df["transport"]=0
test_df["utilities"]=0

# %%
for i in range(test_df.shape[0]):
    for feat in test_df["features"][i]:
        if feat in bows['cats']:
            test_df["cats"][i]=1
        if feat in bows["concierge"]:
            test_df["concierge"]=1
        if feat in bows['dogs']:
            test_df["dogs"][i]=1
        if feat in bows["elevator"]:
            test_df["elevator"]=1
        if feat in bows['health']:
            test_df["health"][i]=1
        if feat in bows["laundry"]:
            test_df["laundry"]=1
        if feat in bows['lowfee']:
            test_df["lowfee"][i]=1
        if feat in bows["nofee"]:
            test_df["nofee"]=1
        if feat in bows['parking']:
            test_df["parking"][i]=1
        if feat in bows["parquet"]:
            test_df["parquet"]=1
        if feat in bows['prewar']:
            test_df["prewar"][i]=1
        if feat in bows["transport"]:
            test_df["transport"]=1
        if feat in bows["utilities"]:
            test_df["utilities"]=1

# %%
features_to_use.append('cats')
features_to_use.append('concierge')
features_to_use.append('dogs')
features_to_use.append('elevator')
features_to_use.append('health')
features_to_use.append('laundry')
features_to_use.append('lowfee')
features_to_use.append('nofee')
features_to_use.append('parking')
features_to_use.append('parquet')
features_to_use.append('prewar')
features_to_use.append('transport')
features_to_use.append('utilities')

# %%
import math
R = 6373.0
location_dict = {
'manhatten_loc' : [40.7527, -73.9943],
'brooklyn_loc' : [45.0761,-73.9442],
'bronx_loc' : [40.8448,-73.8648],
'queens_loc' : [40.7282,-73.7949],
'staten_loc' : [40.5795,-74.1502]}

for location in location_dict.keys():

    lat1 = train_df['latitude'].apply(math.radians)
    lon1 = train_df['longitude'].apply(math.radians)
    lat2 = math.radians(location_dict[location][0])
    lon2 = math.radians(location_dict[location][1])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    def power(x):
        return x**2

    a = (dlat/2).apply(math.sin).apply(power) + lat1.apply(math.cos) * math.cos(lat2) * (dlon/2).apply(math.sin).apply(power)
    c = 2 * a.apply(math.sqrt).apply(math.sin)

    ### Add a new column called distance
    train_df['distance_' + location] = R * c
    features_to_use.append('distance_' + location)

# %%
import math
R = 6373.0
location_dict = {
'manhatten_loc' : [40.7527, -73.9943],
'brooklyn_loc' : [45.0761,-73.9442],
'bronx_loc' : [40.8448,-73.8648],
'queens_loc' : [40.7282,-73.7949],
'staten_loc' : [40.5795,-74.1502]}

for location in location_dict.keys():

    lat1 = test_df['latitude'].apply(math.radians)
    lon1 = test_df['longitude'].apply(math.radians)
    lat2 = math.radians(location_dict[location][0])
    lon2 = math.radians(location_dict[location][1])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    def power(x):
        return x**2

    a = (dlat/2).apply(math.sin).apply(power) + lat1.apply(math.cos) * math.cos(lat2) * (dlon/2).apply(math.sin).apply(power)
    c = 2 * a.apply(math.sqrt).apply(math.sin)

    ### Add a new column called distance
    test_df['distance_' + location] = R * c

# %%
import reverse_geocoder as rg
lat_lon = []
listings = []

for i, j in train_df.iterrows():
    lat_lon.append((j["latitude"], j["longitude"]))
    listings.append(j["listing_id"])
    
results = rg.search(lat_lon) 
nbd = [[listings[i], results[i]['name']] for i in range(0, len(results))]
nbd = pd.DataFrame(data=nbd,columns=["listing_id","neighborhood"])
train_df = pd.merge(train_df, nbd, on='listing_id', how='left')

# %%
lat_lon = []
listings = []
for i, j in test_df.iterrows():
    lat_lon.append((j["latitude"], j["longitude"]))
    listings.append(j["listing_id"])
    
results = rg.search(lat_lon) 
nbd_test = [[listings[i], results[i]['name']] for i in range(0, len(results))]
nbd_test = pd.DataFrame(data=nbd_test,columns=["listing_id","neighborhood"])
test_df = pd.merge(test_df, nbd_test, on='listing_id', how='left')

# %%
features_to_use.append("neighborhood")

# %%
test_df.drop('neighborhood', axis=1, inplace=True)

# %%
train_df["neighborhood"].dtype=='object'
# Out:
# True

# %%
categorical = ["neighborhood"]
for f in categorical:
        if train_df[f].dtype=='object':
            lbl = LabelEncoder()
            lbl.fit(list(train_df[f].values) + list(test_df[f].values))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))

# %%
# Add the number of exclamation signs:
train_df['num_exclamations'] = train_df['description'].apply(lambda x: len(x.split('!')))
test_df['num_exclamations'] = test_df['description'].apply(lambda x: len(x.split('!')))
features_to_use.append("num_exclamations")

# %%
tfidf = CountVectorizer(stop_words='english', max_features=200)
tr_sparse = tfidf.fit_transform(train_df2["features"])
te_sparse = tfidf.transform(test_df2["features"])

# %%
features_to_use=['bathrooms',
 'bedrooms',
 'latitude',
 'longitude',
 'price',
 'price_t',
 'price_per_room',
 'logprice',
 'density',
 'half_bathrooms',
 'num_photos',
 'num_features',
 'num_description_words',
 'listing_id',
 'created_year',
 'created_month',
 'created_day',
 'created_hour',
 'img_days_passed',
 'img_date_month',
 'img_date_week',
 'img_date_day',
 'img_date_dayofweek',
 'img_date_dayofyear',
 'img_date_hour',
 'img_date_monthBeginMidEnd',
 'bed_bath',
 'bed_price',
 'bath_price',
 'bed_photo',
 'price_photo',
 'price_feat',
 'bed_feat',
 'bath_feat',
 'bath_desc',
 'price_desc',
 'total_days',
 'diff_rank',
 'num_rho',
 'num_phi',
 'num_rot15_X',
 'num_rot15_Y',
 'num_rot30_X',
 'num_rot30_Y',
 'num_rot45_X',
 'num_rot45_Y',
 'num_rot60_X',
 'num_rot60_Y',
 'num_cap_share',
 'num_nr_of_lines',
 'num_redacted',
 'num_email',
 'num_phone_nr',
 'manager_level_low',
 'manager_level_medium',
 'manager_level_high',
 'street_address',
 'display_address',
 'manager_id',
 'building_id',
 'compound',
 'neu',
 'neg',
 'distance_manhatten_loc',
 'distance_queens_loc',
 'distance_bronx_loc',
 'distance_brooklyn_loc',
 'distance_staten_loc',
 'cats',
 'concierge',
 'dogs',
 'elevator',
 'health',
 'laundry',
 'lowfee',
 'nofee',
 'parking',
 'parquet',
 'prewar',
 'transport',
 'utilities']

# %%
train_X = sparse.hstack([train_df[features_to_use], tr_sparse]).tocsr()
test_X = sparse.hstack([test_df[features_to_use], te_sparse]).tocsr()

target_num_map = {'high':0, 'medium':1, 'low':2}
train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

# %%
from sklearn import model_selection, preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
features_to_use=['bathrooms',
 'bedrooms',
 'latitude',
 'longitude',
 'price',
 'price_t',
 'price_per_room',
 'logprice',
 'density',
 'half_bathrooms',
 'num_photos',
 'num_features',
 'num_description_words',
 'listing_id',
 'created_year',
 'created_month',
 'created_day',
 'created_hour',
 'img_days_passed',
 'img_date_month',
 'img_date_week',
 'img_date_day',
 'img_date_dayofweek',
 'img_date_dayofyear',
 'img_date_hour',
 'img_date_monthBeginMidEnd',
 'bed_bath',
 'bed_price',
 'bath_price',
 'bed_photo',
 'price_photo',
 'price_feat',
 'bed_feat',
 'bath_feat',
 'bath_desc',
 'price_desc',
 'total_days',
 'diff_rank',
 'num_rho',
 'num_phi',
 'num_rot15_X',
 'num_rot15_Y',
 'num_rot30_X',
 'num_rot30_Y',
 'num_rot45_X',
 'num_rot45_Y',
 'num_rot60_X',
 'num_rot60_Y',
 'num_cap_share',
 'num_nr_of_lines',
 'num_redacted',
 'num_email',
 'num_phone_nr',
 'manager_level_low',
 'manager_level_medium',
 'manager_level_high',
 'street_address',
 'display_address',
 'manager_id',
 'building_id',
 'compound',
 'neu',
 'neg',
 'distance_manhatten_loc',
 'distance_queens_loc',
 'distance_bronx_loc',
 'distance_brooklyn_loc',
 'distance_staten_loc',]
 #'cats',
 #'concierge',
 #'dogs',
 #'elevator',
 #'health',
 #'laundry',
 #'lowfee',
 #'nofee',
 #'parking',
 #'parquet',
 #'prewar',
 #'transport',
 #'utilities']

# %%
cv_scores = []
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2016)
for dev_index, val_index in kf.split(range(train_X.shape[0])):
        dev_X, val_X = train_X[dev_index,:], train_X[val_index,:]
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        preds, model = runXGB(dev_X, dev_y, val_X, val_y)
        cv_scores.append(log_loss(val_y, preds))
        print(cv_scores)
        break
# Out:
# [0]	train-mlogloss:1.08384	test-mlogloss:1.08418
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 20 rounds.
# [1]	train-mlogloss:1.06959	test-mlogloss:1.07033
# [2]	train-mlogloss:1.05575	test-mlogloss:1.05684
# [3]	train-mlogloss:1.04243	test-mlogloss:1.04389
# [4]	train-mlogloss:1.02949	test-mlogloss:1.03131
# [5]	train-mlogloss:1.01704	test-mlogloss:1.01923
# [6]	train-mlogloss:1.00501	test-mlogloss:1.00747
# [7]	train-mlogloss:0.993372	test-mlogloss:0.996174
# [8]	train-mlogloss:0.98199	test-mlogloss:0.985159
# [9]	train-mlogloss:0.971038	test-mlogloss:0.974522
# [10]	train-mlogloss:0.960377	test-mlogloss:0.96422
# [11]	train-mlogloss:0.950209	test-mlogloss:0.95436
# [12]	train-mlogloss:0.940301	test-mlogloss:0.9448
# [13]	train-mlogloss:0.93062	test-mlogloss:0.935405
# [14]	train-mlogloss:0.921194	test-mlogloss:0.92624
# [15]	train-mlogloss:0.911935	test-mlogloss:0.917366
# [16]	train-mlogloss:0.902925	test-mlogloss:0.908686
# [17]	train-mlogloss:0.894345	test-mlogloss:0.900385
# [18]	train-mlogloss:0.885966	test-mlogloss:0.892385
# [19]	train-mlogloss:0.877744	test-mlogloss:0.884474
# [20]	train-mlogloss:0.869813	test-mlogloss:0.876829
# [21]	train-mlogloss:0.861972	test-mlogloss:0.86928
# [22]	train-mlogloss:0.85447	test-mlogloss:0.862091
# [23]	train-mlogloss:0.847211	test-mlogloss:0.855099
# [24]	train-mlogloss:0.840042	test-mlogloss:0.848197
# [25]	train-mlogloss:0.833054	test-mlogloss:0.84154
# [26]	train-mlogloss:0.826253	test-mlogloss:0.835077
# [27]	train-mlogloss:0.819644	test-mlogloss:0.828828
# [28]	train-mlogloss:0.813215	test-mlogloss:0.822678
# [29]	train-mlogloss:0.806914	test-mlogloss:0.816675
# [30]	train-mlogloss:0.800808	test-mlogloss:0.810898
# [31]	train-mlogloss:0.794845	test-mlogloss:0.805304
# [32]	train-mlogloss:0.788997	test-mlogloss:0.79979
# [33]	train-mlogloss:0.783294	test-mlogloss:0.794386
# [34]	train-mlogloss:0.777705	test-mlogloss:0.789086
# [35]	train-mlogloss:0.772301	test-mlogloss:0.783968
# [36]	train-mlogloss:0.767046	test-mlogloss:0.778994
# [37]	train-mlogloss:0.76191	test-mlogloss:0.774181
# [38]	train-mlogloss:0.756914	test-mlogloss:0.769544
# [39]	train-mlogloss:0.752036	test-mlogloss:0.764961
# [40]	train-mlogloss:0.74725	test-mlogloss:0.76046
# [41]	train-mlogloss:0.742612	test-mlogloss:0.756071
# [42]	train-mlogloss:0.738063	test-mlogloss:0.751811
# [43]	train-mlogloss:0.733635	test-mlogloss:0.747652
# [44]	train-mlogloss:0.729274	test-mlogloss:0.743518
# [45]	train-mlogloss:0.725067	test-mlogloss:0.739569
# [46]	train-mlogloss:0.721005	test-mlogloss:0.735803
# [47]	train-mlogloss:0.717011	test-mlogloss:0.732068
# [48]	train-mlogloss:0.713069	test-mlogloss:0.7284
# [49]	train-mlogloss:0.709257	test-mlogloss:0.724826
# [50]	train-mlogloss:0.705544	test-mlogloss:0.721357
# [51]	train-mlogloss:0.701873	test-mlogloss:0.717938
# [52]	train-mlogloss:0.698289	test-mlogloss:0.714593
# [53]	train-mlogloss:0.694724	test-mlogloss:0.71128
# [54]	train-mlogloss:0.691261	test-mlogloss:0.708059
# [55]	train-mlogloss:0.687902	test-mlogloss:0.704943
# [56]	train-mlogloss:0.684642	test-mlogloss:0.70193
# [57]	train-mlogloss:0.681414	test-mlogloss:0.698991
# [58]	train-mlogloss:0.678245	test-mlogloss:0.696116
# [59]	train-mlogloss:0.675113	test-mlogloss:0.693224
# [60]	train-mlogloss:0.672133	test-mlogloss:0.690484
# [61]	train-mlogloss:0.669226	test-mlogloss:0.687863
# [62]	train-mlogloss:0.666279	test-mlogloss:0.685107
# [63]	train-mlogloss:0.663431	test-mlogloss:0.682518
# [64]	train-mlogloss:0.66069	test-mlogloss:0.680077
# [65]	train-mlogloss:0.657983	test-mlogloss:0.677608
# [66]	train-mlogloss:0.655279	test-mlogloss:0.675148
# [67]	train-mlogloss:0.652651	test-mlogloss:0.672736
# [68]	train-mlogloss:0.650052	test-mlogloss:0.670421
# [69]	train-mlogloss:0.647568	test-mlogloss:0.668135
# [70]	train-mlogloss:0.645086	test-mlogloss:0.665881
# [71]	train-mlogloss:0.642686	test-mlogloss:0.663722
# [72]	train-mlogloss:0.640291	test-mlogloss:0.661578
# [73]	train-mlogloss:0.637905	test-mlogloss:0.659419
# [74]	train-mlogloss:0.635631	test-mlogloss:0.657359
# [75]	train-mlogloss:0.633457	test-mlogloss:0.65547
# [76]	train-mlogloss:0.631292	test-mlogloss:0.653525
# [77]	train-mlogloss:0.629112	test-mlogloss:0.651581
# [78]	train-mlogloss:0.627046	test-mlogloss:0.649712
# [79]	train-mlogloss:0.624958	test-mlogloss:0.647885
# [80]	train-mlogloss:0.622934	test-mlogloss:0.646112
# [81]	train-mlogloss:0.620973	test-mlogloss:0.644372
# [82]	train-mlogloss:0.619056	test-mlogloss:0.642692
# [83]	train-mlogloss:0.61726	test-mlogloss:0.641086
# [84]	train-mlogloss:0.615321	test-mlogloss:0.639385
# [85]	train-mlogloss:0.613448	test-mlogloss:0.637703
# [86]	train-mlogloss:0.611624	test-mlogloss:0.636122
# [87]	train-mlogloss:0.609844	test-mlogloss:0.634611
# [88]	train-mlogloss:0.608125	test-mlogloss:0.633118
# [89]	train-mlogloss:0.606372	test-mlogloss:0.631584
# [90]	train-mlogloss:0.604655	test-mlogloss:0.6301
# [91]	train-mlogloss:0.603012	test-mlogloss:0.628627
# [92]	train-mlogloss:0.601377	test-mlogloss:0.6272
# [93]	train-mlogloss:0.599785	test-mlogloss:0.625881
# [94]	train-mlogloss:0.598181	test-mlogloss:0.624486
# [95]	train-mlogloss:0.596643	test-mlogloss:0.623179
# [96]	train-mlogloss:0.595138	test-mlogloss:0.621868
# [97]	train-mlogloss:0.593662	test-mlogloss:0.620586
# [98]	train-mlogloss:0.592124	test-mlogloss:0.619324
# [99]	train-mlogloss:0.590639	test-mlogloss:0.618039
# [100]	train-mlogloss:0.589169	test-mlogloss:0.616834
# [101]	train-mlogloss:0.587792	test-mlogloss:0.615684
# [102]	train-mlogloss:0.586425	test-mlogloss:0.614547
# [103]	train-mlogloss:0.585046	test-mlogloss:0.613413
# [104]	train-mlogloss:0.58368	test-mlogloss:0.61227
# [105]	train-mlogloss:0.582381	test-mlogloss:0.611201
# [106]	train-mlogloss:0.581072	test-mlogloss:0.610181
# [107]	train-mlogloss:0.579796	test-mlogloss:0.609131
# [108]	train-mlogloss:0.5785	test-mlogloss:0.608048
# [109]	train-mlogloss:0.57723	test-mlogloss:0.607014
# [110]	train-mlogloss:0.575899	test-mlogloss:0.605925
# [111]	train-mlogloss:0.574736	test-mlogloss:0.604932
# [112]	train-mlogloss:0.573519	test-mlogloss:0.603952
# [113]	train-mlogloss:0.572354	test-mlogloss:0.603045
# [114]	train-mlogloss:0.57116	test-mlogloss:0.602047
# [115]	train-mlogloss:0.569996	test-mlogloss:0.601091
# [116]	train-mlogloss:0.568818	test-mlogloss:0.60019
# [117]	train-mlogloss:0.567704	test-mlogloss:0.599294
# [118]	train-mlogloss:0.566657	test-mlogloss:0.598469
# [119]	train-mlogloss:0.565581	test-mlogloss:0.597584
# [120]	train-mlogloss:0.564541	test-mlogloss:0.596741
# [121]	train-mlogloss:0.563491	test-mlogloss:0.595915
# [122]	train-mlogloss:0.562509	test-mlogloss:0.595162
# [123]	train-mlogloss:0.561581	test-mlogloss:0.594398
# [124]	train-mlogloss:0.560555	test-mlogloss:0.593605
# [125]	train-mlogloss:0.559541	test-mlogloss:0.592779
# [126]	train-mlogloss:0.558507	test-mlogloss:0.59197
# [127]	train-mlogloss:0.557506	test-mlogloss:0.591215
# [128]	train-mlogloss:0.556551	test-mlogloss:0.590439
# [129]	train-mlogloss:0.55563	test-mlogloss:0.589729
# [130]	train-mlogloss:0.554655	test-mlogloss:0.588959
# [131]	train-mlogloss:0.553723	test-mlogloss:0.588193
# [132]	train-mlogloss:0.552822	test-mlogloss:0.587507
# [133]	train-mlogloss:0.551938	test-mlogloss:0.586827
# [134]	train-mlogloss:0.551002	test-mlogloss:0.586088
# [135]	train-mlogloss:0.55014	test-mlogloss:0.585429
# [136]	train-mlogloss:0.549277	test-mlogloss:0.584756
# [137]	train-mlogloss:0.548456	test-mlogloss:0.584131
# [138]	train-mlogloss:0.54755	test-mlogloss:0.583421
# [139]	train-mlogloss:0.5467	test-mlogloss:0.582819
# [140]	train-mlogloss:0.545866	test-mlogloss:0.582238
# [141]	train-mlogloss:0.545092	test-mlogloss:0.58162
# [142]	train-mlogloss:0.544316	test-mlogloss:0.581033
# [143]	train-mlogloss:0.543506	test-mlogloss:0.580421
# [144]	train-mlogloss:0.542752	test-mlogloss:0.579865
# [145]	train-mlogloss:0.54197	test-mlogloss:0.579263
# [146]	train-mlogloss:0.541191	test-mlogloss:0.578646
# [147]	train-mlogloss:0.54046	test-mlogloss:0.578135
# [148]	train-mlogloss:0.539705	test-mlogloss:0.57755
# [149]	train-mlogloss:0.538857	test-mlogloss:0.576933
# [150]	train-mlogloss:0.538067	test-mlogloss:0.576349
# [151]	train-mlogloss:0.537339	test-mlogloss:0.575826
# [152]	train-mlogloss:0.536646	test-mlogloss:0.575328
# [153]	train-mlogloss:0.535865	test-mlogloss:0.574753
# [154]	train-mlogloss:0.535093	test-mlogloss:0.574139
# [155]	train-mlogloss:0.534397	test-mlogloss:0.573661
# [156]	train-mlogloss:0.533691	test-mlogloss:0.573121
# [157]	train-mlogloss:0.532878	test-mlogloss:0.572552
# [158]	train-mlogloss:0.532293	test-mlogloss:0.572108
# [159]	train-mlogloss:0.531542	test-mlogloss:0.57157
# [160]	train-mlogloss:0.530967	test-mlogloss:0.571172
# [161]	train-mlogloss:0.530263	test-mlogloss:0.570727
# [162]	train-mlogloss:0.529642	test-mlogloss:0.570304
# [163]	train-mlogloss:0.529057	test-mlogloss:0.56989
# [164]	train-mlogloss:0.528446	test-mlogloss:0.569453
# [165]	train-mlogloss:0.527769	test-mlogloss:0.568997
# [166]	train-mlogloss:0.527165	test-mlogloss:0.568619
# [167]	train-mlogloss:0.526507	test-mlogloss:0.568145
# [168]	train-mlogloss:0.525803	test-mlogloss:0.567695
# [169]	train-mlogloss:0.525224	test-mlogloss:0.567295
# [170]	train-mlogloss:0.524639	test-mlogloss:0.566889
# [171]	train-mlogloss:0.524067	test-mlogloss:0.566503
# [172]	train-mlogloss:0.523515	test-mlogloss:0.566123
# [173]	train-mlogloss:0.522978	test-mlogloss:0.565773
# [174]	train-mlogloss:0.522472	test-mlogloss:0.565412
# [175]	train-mlogloss:0.521793	test-mlogloss:0.564933
# [176]	train-mlogloss:0.521186	test-mlogloss:0.564533
# [177]	train-mlogloss:0.520569	test-mlogloss:0.564135
# [178]	train-mlogloss:0.52006	test-mlogloss:0.563778
# [179]	train-mlogloss:0.519531	test-mlogloss:0.563422
# [180]	train-mlogloss:0.519038	test-mlogloss:0.563087
# [181]	train-mlogloss:0.518385	test-mlogloss:0.56273
# [182]	train-mlogloss:0.517866	test-mlogloss:0.562369
# [183]	train-mlogloss:0.517417	test-mlogloss:0.562092
# [184]	train-mlogloss:0.5169	test-mlogloss:0.561772
# [185]	train-mlogloss:0.516394	test-mlogloss:0.561464
# [186]	train-mlogloss:0.515842	test-mlogloss:0.561107
# [187]	train-mlogloss:0.515293	test-mlogloss:0.56079
# [188]	train-mlogloss:0.514743	test-mlogloss:0.560492
# [189]	train-mlogloss:0.51427	test-mlogloss:0.560177
# [190]	train-mlogloss:0.513738	test-mlogloss:0.559818
# [191]	train-mlogloss:0.513202	test-mlogloss:0.559516
# [192]	train-mlogloss:0.512683	test-mlogloss:0.559211
# [193]	train-mlogloss:0.5122	test-mlogloss:0.558916
# [194]	train-mlogloss:0.511758	test-mlogloss:0.558667
# [195]	train-mlogloss:0.511281	test-mlogloss:0.558402
# [196]	train-mlogloss:0.510817	test-mlogloss:0.558154
# [197]	train-mlogloss:0.510296	test-mlogloss:0.557883
# [198]	train-mlogloss:0.509882	test-mlogloss:0.557636
# [199]	train-mlogloss:0.509356	test-mlogloss:0.557305
# [200]	train-mlogloss:0.508859	test-mlogloss:0.556983
# [201]	train-mlogloss:0.508327	test-mlogloss:0.556765
# [202]	train-mlogloss:0.507875	test-mlogloss:0.556461
# [203]	train-mlogloss:0.507468	test-mlogloss:0.556203
# [204]	train-mlogloss:0.507	test-mlogloss:0.555953
# [205]	train-mlogloss:0.506511	test-mlogloss:0.555732
# [206]	train-mlogloss:0.505979	test-mlogloss:0.55547
# [207]	train-mlogloss:0.505562	test-mlogloss:0.555234
# [208]	train-mlogloss:0.505138	test-mlogloss:0.554978
# [209]	train-mlogloss:0.504698	test-mlogloss:0.554719
# [210]	train-mlogloss:0.504254	test-mlogloss:0.554487
# [211]	train-mlogloss:0.503714	test-mlogloss:0.554211
# [212]	train-mlogloss:0.50319	test-mlogloss:0.553914
# [213]	train-mlogloss:0.502731	test-mlogloss:0.553687
# [214]	train-mlogloss:0.502281	test-mlogloss:0.553445
# [215]	train-mlogloss:0.501921	test-mlogloss:0.553267
# [216]	train-mlogloss:0.501491	test-mlogloss:0.553045
# [217]	train-mlogloss:0.500991	test-mlogloss:0.552794
# [218]	train-mlogloss:0.500562	test-mlogloss:0.552593
# [219]	train-mlogloss:0.500118	test-mlogloss:0.552343
# [220]	train-mlogloss:0.499702	test-mlogloss:0.552109
# [221]	train-mlogloss:0.49931	test-mlogloss:0.551899
# [222]	train-mlogloss:0.498865	test-mlogloss:0.551642
# [223]	train-mlogloss:0.498407	test-mlogloss:0.551434
# [224]	train-mlogloss:0.498019	test-mlogloss:0.551259
# [225]	train-mlogloss:0.497591	test-mlogloss:0.551028
# [226]	train-mlogloss:0.497177	test-mlogloss:0.550816
# [227]	train-mlogloss:0.496792	test-mlogloss:0.550601
# [228]	train-mlogloss:0.496392	test-mlogloss:0.550416
# [229]	train-mlogloss:0.495979	test-mlogloss:0.550198
# [230]	train-mlogloss:0.495553	test-mlogloss:0.549935
# [231]	train-mlogloss:0.495122	test-mlogloss:0.549695
# [232]	train-mlogloss:0.494763	test-mlogloss:0.549478
# [233]	train-mlogloss:0.494395	test-mlogloss:0.549286
# [234]	train-mlogloss:0.493968	test-mlogloss:0.549087
# [235]	train-mlogloss:0.493596	test-mlogloss:0.548903
# [236]	train-mlogloss:0.493223	test-mlogloss:0.548708
# [237]	train-mlogloss:0.492793	test-mlogloss:0.548502
# [238]	train-mlogloss:0.492371	test-mlogloss:0.548343
# [239]	train-mlogloss:0.492023	test-mlogloss:0.548151
# [240]	train-mlogloss:0.491632	test-mlogloss:0.547993
# [241]	train-mlogloss:0.491217	test-mlogloss:0.547798
# [242]	train-mlogloss:0.490834	test-mlogloss:0.547643
# [243]	train-mlogloss:0.490561	test-mlogloss:0.54748
# [244]	train-mlogloss:0.490169	test-mlogloss:0.547265
# [245]	train-mlogloss:0.48969	test-mlogloss:0.547044
# [246]	train-mlogloss:0.489278	test-mlogloss:0.546869
# [247]	train-mlogloss:0.488952	test-mlogloss:0.546718
# [248]	train-mlogloss:0.488577	test-mlogloss:0.546525
# [249]	train-mlogloss:0.488254	test-mlogloss:0.546364
# [250]	train-mlogloss:0.487889	test-mlogloss:0.546151
# [251]	train-mlogloss:0.487482	test-mlogloss:0.54595
# [252]	train-mlogloss:0.487058	test-mlogloss:0.545772
# [253]	train-mlogloss:0.486615	test-mlogloss:0.545574
# [254]	train-mlogloss:0.486252	test-mlogloss:0.545407
# [255]	train-mlogloss:0.485864	test-mlogloss:0.545182
# [256]	train-mlogloss:0.485597	test-mlogloss:0.545057
# [257]	train-mlogloss:0.48519	test-mlogloss:0.544874
# [258]	train-mlogloss:0.48489	test-mlogloss:0.544747
# [259]	train-mlogloss:0.484466	test-mlogloss:0.544582
# [260]	train-mlogloss:0.484144	test-mlogloss:0.544442
# [261]	train-mlogloss:0.483799	test-mlogloss:0.544269
# [262]	train-mlogloss:0.48346	test-mlogloss:0.544088
# [263]	train-mlogloss:0.48311	test-mlogloss:0.543878
# [264]	train-mlogloss:0.482681	test-mlogloss:0.543721
# [265]	train-mlogloss:0.482374	test-mlogloss:0.543581
# [266]	train-mlogloss:0.482052	test-mlogloss:0.54343
# [267]	train-mlogloss:0.481745	test-mlogloss:0.543283
# [268]	train-mlogloss:0.481365	test-mlogloss:0.543087
# [269]	train-mlogloss:0.481084	test-mlogloss:0.542955
# [270]	train-mlogloss:0.480717	test-mlogloss:0.542777
# [271]	train-mlogloss:0.480334	test-mlogloss:0.542644
# [272]	train-mlogloss:0.480014	test-mlogloss:0.542511
# [273]	train-mlogloss:0.47974	test-mlogloss:0.54235
# [274]	train-mlogloss:0.479449	test-mlogloss:0.542201
# [275]	train-mlogloss:0.479021	test-mlogloss:0.542031
# [276]	train-mlogloss:0.47869	test-mlogloss:0.541866
# [277]	train-mlogloss:0.478364	test-mlogloss:0.541725
# [278]	train-mlogloss:0.478042	test-mlogloss:0.541587
# [279]	train-mlogloss:0.477643	test-mlogloss:0.54142
# [280]	train-mlogloss:0.477247	test-mlogloss:0.5413
# [281]	train-mlogloss:0.476878	test-mlogloss:0.54117
# [282]	train-mlogloss:0.476552	test-mlogloss:0.541055
# [283]	train-mlogloss:0.476203	test-mlogloss:0.540972
# [284]	train-mlogloss:0.47593	test-mlogloss:0.540867
# [285]	train-mlogloss:0.475649	test-mlogloss:0.540762
# [286]	train-mlogloss:0.475307	test-mlogloss:0.540615
# [287]	train-mlogloss:0.475003	test-mlogloss:0.540506
# [288]	train-mlogloss:0.474587	test-mlogloss:0.540283
# [289]	train-mlogloss:0.474221	test-mlogloss:0.54013
# [290]	train-mlogloss:0.4739	test-mlogloss:0.54002
# [291]	train-mlogloss:0.473633	test-mlogloss:0.539882
# [292]	train-mlogloss:0.473318	test-mlogloss:0.539765
# [293]	train-mlogloss:0.472963	test-mlogloss:0.539615
# [294]	train-mlogloss:0.472662	test-mlogloss:0.539501
# [295]	train-mlogloss:0.472352	test-mlogloss:0.539333
# [296]	train-mlogloss:0.471961	test-mlogloss:0.539219
# [297]	train-mlogloss:0.471606	test-mlogloss:0.539091
# [298]	train-mlogloss:0.471246	test-mlogloss:0.538957
# [299]	train-mlogloss:0.470896	test-mlogloss:0.538827
# [300]	train-mlogloss:0.470591	test-mlogloss:0.538728
# [301]	train-mlogloss:0.470268	test-mlogloss:0.538589
# [302]	train-mlogloss:0.469903	test-mlogloss:0.538461
# [303]	train-mlogloss:0.469563	test-mlogloss:0.538348
# [304]	train-mlogloss:0.469284	test-mlogloss:0.53823
# [305]	train-mlogloss:0.468987	test-mlogloss:0.538111
# [306]	train-mlogloss:0.468723	test-mlogloss:0.538001
# [307]	train-mlogloss:0.468423	test-mlogloss:0.537874
# [308]	train-mlogloss:0.468111	test-mlogloss:0.537742
# [309]	train-mlogloss:0.467796	test-mlogloss:0.537624
# [310]	train-mlogloss:0.467504	test-mlogloss:0.537554
# [311]	train-mlogloss:0.467186	test-mlogloss:0.537453
# [312]	train-mlogloss:0.466969	test-mlogloss:0.537385
# [313]	train-mlogloss:0.466702	test-mlogloss:0.537285
# [314]	train-mlogloss:0.466483	test-mlogloss:0.53718
# [315]	train-mlogloss:0.466172	test-mlogloss:0.537079
# [316]	train-mlogloss:0.46587	test-mlogloss:0.536994
# [317]	train-mlogloss:0.465556	test-mlogloss:0.536891
# [318]	train-mlogloss:0.465291	test-mlogloss:0.536766
# [319]	train-mlogloss:0.464997	test-mlogloss:0.536659
# [320]	train-mlogloss:0.464637	test-mlogloss:0.53652
# [321]	train-mlogloss:0.464373	test-mlogloss:0.536393
# [322]	train-mlogloss:0.464112	test-mlogloss:0.536294
# [323]	train-mlogloss:0.463849	test-mlogloss:0.536171
# [324]	train-mlogloss:0.463617	test-mlogloss:0.536068
# [325]	train-mlogloss:0.463343	test-mlogloss:0.535983
# [326]	train-mlogloss:0.463093	test-mlogloss:0.535905
# [327]	train-mlogloss:0.462864	test-mlogloss:0.535798
# [328]	train-mlogloss:0.462615	test-mlogloss:0.535716
# [329]	train-mlogloss:0.462355	test-mlogloss:0.535597
# [330]	train-mlogloss:0.4621	test-mlogloss:0.535521
# [331]	train-mlogloss:0.461768	test-mlogloss:0.535413
# [332]	train-mlogloss:0.461447	test-mlogloss:0.535305
# [333]	train-mlogloss:0.461176	test-mlogloss:0.535195
# [334]	train-mlogloss:0.46088	test-mlogloss:0.535139
# [335]	train-mlogloss:0.460599	test-mlogloss:0.53504
# [336]	train-mlogloss:0.460355	test-mlogloss:0.534954
# [337]	train-mlogloss:0.46002	test-mlogloss:0.534852
# [338]	train-mlogloss:0.459742	test-mlogloss:0.534769
# [339]	train-mlogloss:0.459398	test-mlogloss:0.534687
# [340]	train-mlogloss:0.459127	test-mlogloss:0.534566
# [341]	train-mlogloss:0.458857	test-mlogloss:0.534456
# [342]	train-mlogloss:0.458604	test-mlogloss:0.534359
# [343]	train-mlogloss:0.458343	test-mlogloss:0.534239
# [344]	train-mlogloss:0.458098	test-mlogloss:0.534112
# [345]	train-mlogloss:0.457777	test-mlogloss:0.534017
# [346]	train-mlogloss:0.457548	test-mlogloss:0.533937
# [347]	train-mlogloss:0.457311	test-mlogloss:0.533869
# [348]	train-mlogloss:0.457005	test-mlogloss:0.533739
# [349]	train-mlogloss:0.456721	test-mlogloss:0.533678
# [350]	train-mlogloss:0.456462	test-mlogloss:0.533606
# [351]	train-mlogloss:0.456158	test-mlogloss:0.533513
# [352]	train-mlogloss:0.455936	test-mlogloss:0.533434
# [353]	train-mlogloss:0.455643	test-mlogloss:0.533328
# [354]	train-mlogloss:0.455328	test-mlogloss:0.533273
# [355]	train-mlogloss:0.455042	test-mlogloss:0.533179
# [356]	train-mlogloss:0.454836	test-mlogloss:0.533087
# [357]	train-mlogloss:0.454539	test-mlogloss:0.533047
# [358]	train-mlogloss:0.454352	test-mlogloss:0.532974
# [359]	train-mlogloss:0.454084	test-mlogloss:0.532921
# [360]	train-mlogloss:0.453791	test-mlogloss:0.532833
# [361]	train-mlogloss:0.453525	test-mlogloss:0.532786
# [362]	train-mlogloss:0.453195	test-mlogloss:0.5327
# [363]	train-mlogloss:0.452947	test-mlogloss:0.53258
# [364]	train-mlogloss:0.452729	test-mlogloss:0.532541
# [365]	train-mlogloss:0.452496	test-mlogloss:0.532476
# [366]	train-mlogloss:0.45223	test-mlogloss:0.532414
# [367]	train-mlogloss:0.451943	test-mlogloss:0.532313
# [368]	train-mlogloss:0.451642	test-mlogloss:0.53221
# [369]	train-mlogloss:0.451371	test-mlogloss:0.532126
# [370]	train-mlogloss:0.451113	test-mlogloss:0.532063
# [371]	train-mlogloss:0.450829	test-mlogloss:0.531969
# [372]	train-mlogloss:0.450583	test-mlogloss:0.53192
# [373]	train-mlogloss:0.450368	test-mlogloss:0.531869
# [374]	train-mlogloss:0.450119	test-mlogloss:0.531775
# [375]	train-mlogloss:0.449887	test-mlogloss:0.531724
# [376]	train-mlogloss:0.449621	test-mlogloss:0.531671
# [377]	train-mlogloss:0.449399	test-mlogloss:0.531624
# [378]	train-mlogloss:0.449142	test-mlogloss:0.531552
# [379]	train-mlogloss:0.448943	test-mlogloss:0.531524
# [380]	train-mlogloss:0.448692	test-mlogloss:0.531447
# [381]	train-mlogloss:0.448358	test-mlogloss:0.531345
# [382]	train-mlogloss:0.448206	test-mlogloss:0.531322
# [383]	train-mlogloss:0.448011	test-mlogloss:0.531254
# [384]	train-mlogloss:0.447756	test-mlogloss:0.531151
# [385]	train-mlogloss:0.447584	test-mlogloss:0.531095
# [386]	train-mlogloss:0.447262	test-mlogloss:0.531022
# [387]	train-mlogloss:0.447041	test-mlogloss:0.53093
# [388]	train-mlogloss:0.44669	test-mlogloss:0.530865
# [389]	train-mlogloss:0.44645	test-mlogloss:0.530766
# [390]	train-mlogloss:0.44626	test-mlogloss:0.530685
# [391]	train-mlogloss:0.446015	test-mlogloss:0.530611
# [392]	train-mlogloss:0.445845	test-mlogloss:0.530553
# [393]	train-mlogloss:0.44562	test-mlogloss:0.530465
# [394]	train-mlogloss:0.445398	test-mlogloss:0.530401
# [395]	train-mlogloss:0.445068	test-mlogloss:0.530317
# [396]	train-mlogloss:0.444814	test-mlogloss:0.530261
# [397]	train-mlogloss:0.444582	test-mlogloss:0.530235
# [398]	train-mlogloss:0.444277	test-mlogloss:0.530169
# [399]	train-mlogloss:0.444052	test-mlogloss:0.530092
# [400]	train-mlogloss:0.443846	test-mlogloss:0.530042
# [401]	train-mlogloss:0.443567	test-mlogloss:0.530025
# [402]	train-mlogloss:0.443345	test-mlogloss:0.529967
# [403]	train-mlogloss:0.443048	test-mlogloss:0.529882
# [404]	train-mlogloss:0.442791	test-mlogloss:0.52981
# [405]	train-mlogloss:0.442545	test-mlogloss:0.529737
# [406]	train-mlogloss:0.442377	test-mlogloss:0.529726
# [407]	train-mlogloss:0.442136	test-mlogloss:0.529697
# [408]	train-mlogloss:0.441948	test-mlogloss:0.529635
# [409]	train-mlogloss:0.441755	test-mlogloss:0.529576
# [410]	train-mlogloss:0.441545	test-mlogloss:0.529496
# [411]	train-mlogloss:0.441342	test-mlogloss:0.529448
# [412]	train-mlogloss:0.44112	test-mlogloss:0.529393
# [413]	train-mlogloss:0.440908	test-mlogloss:0.529353
# [414]	train-mlogloss:0.440748	test-mlogloss:0.529309
# [415]	train-mlogloss:0.440504	test-mlogloss:0.529245
# [416]	train-mlogloss:0.440273	test-mlogloss:0.529209
# [417]	train-mlogloss:0.439979	test-mlogloss:0.529178
# [418]	train-mlogloss:0.439714	test-mlogloss:0.529141
# [419]	train-mlogloss:0.439497	test-mlogloss:0.529076
# [420]	train-mlogloss:0.439256	test-mlogloss:0.529058
# [421]	train-mlogloss:0.438948	test-mlogloss:0.529025
# [422]	train-mlogloss:0.438724	test-mlogloss:0.528955
# [423]	train-mlogloss:0.438419	test-mlogloss:0.528924
# [424]	train-mlogloss:0.438144	test-mlogloss:0.528845
# [425]	train-mlogloss:0.43792	test-mlogloss:0.528801
# [426]	train-mlogloss:0.437722	test-mlogloss:0.528743
# [427]	train-mlogloss:0.437481	test-mlogloss:0.528656
# [428]	train-mlogloss:0.437299	test-mlogloss:0.528609
# [429]	train-mlogloss:0.437111	test-mlogloss:0.528555
# [430]	train-mlogloss:0.43688	test-mlogloss:0.528485
# [431]	train-mlogloss:0.436632	test-mlogloss:0.5284
# [432]	train-mlogloss:0.436384	test-mlogloss:0.528336
# [433]	train-mlogloss:0.43612	test-mlogloss:0.528273
# [434]	train-mlogloss:0.435944	test-mlogloss:0.528243
# [435]	train-mlogloss:0.435741	test-mlogloss:0.528189
# [436]	train-mlogloss:0.435453	test-mlogloss:0.528161
# [437]	train-mlogloss:0.435196	test-mlogloss:0.528098
# [438]	train-mlogloss:0.434946	test-mlogloss:0.528036
# [439]	train-mlogloss:0.434749	test-mlogloss:0.527948
# [440]	train-mlogloss:0.434451	test-mlogloss:0.527873
# [441]	train-mlogloss:0.434242	test-mlogloss:0.527793
# [442]	train-mlogloss:0.434107	test-mlogloss:0.527765
# [443]	train-mlogloss:0.43387	test-mlogloss:0.527713
# [444]	train-mlogloss:0.433672	test-mlogloss:0.527711
# [445]	train-mlogloss:0.433476	test-mlogloss:0.527677
# [446]	train-mlogloss:0.433242	test-mlogloss:0.527611
# [447]	train-mlogloss:0.433043	test-mlogloss:0.527552
# [448]	train-mlogloss:0.432845	test-mlogloss:0.527503
# [449]	train-mlogloss:0.432634	test-mlogloss:0.527422
# [450]	train-mlogloss:0.432364	test-mlogloss:0.527353
# [451]	train-mlogloss:0.432077	test-mlogloss:0.527283
# [452]	train-mlogloss:0.431789	test-mlogloss:0.527245
# [453]	train-mlogloss:0.431563	test-mlogloss:0.527188
# [454]	train-mlogloss:0.431327	test-mlogloss:0.527115
# [455]	train-mlogloss:0.431106	test-mlogloss:0.527054
# [456]	train-mlogloss:0.430864	test-mlogloss:0.527046
# [457]	train-mlogloss:0.430671	test-mlogloss:0.526977
# [458]	train-mlogloss:0.430416	test-mlogloss:0.526918
# [459]	train-mlogloss:0.430239	test-mlogloss:0.526917
# [460]	train-mlogloss:0.430047	test-mlogloss:0.52687
# [461]	train-mlogloss:0.429806	test-mlogloss:0.526793
# [462]	train-mlogloss:0.429571	test-mlogloss:0.526757
# [463]	train-mlogloss:0.42934	test-mlogloss:0.526704
# [464]	train-mlogloss:0.42908	test-mlogloss:0.526624
# [465]	train-mlogloss:0.428801	test-mlogloss:0.526589
# [466]	train-mlogloss:0.428567	test-mlogloss:0.526548
# [467]	train-mlogloss:0.428383	test-mlogloss:0.526512
# [468]	train-mlogloss:0.428158	test-mlogloss:0.526454
# [469]	train-mlogloss:0.427986	test-mlogloss:0.526428
# [470]	train-mlogloss:0.427856	test-mlogloss:0.526381
# [471]	train-mlogloss:0.427645	test-mlogloss:0.526307
# [472]	train-mlogloss:0.427456	test-mlogloss:0.52625
# [473]	train-mlogloss:0.427279	test-mlogloss:0.526212
# [474]	train-mlogloss:0.427093	test-mlogloss:0.526177
# [475]	train-mlogloss:0.426881	test-mlogloss:0.526142
# [476]	train-mlogloss:0.426682	test-mlogloss:0.526086
# [477]	train-mlogloss:0.426526	test-mlogloss:0.526016
# [478]	train-mlogloss:0.426316	test-mlogloss:0.525959
# [479]	train-mlogloss:0.42607	test-mlogloss:0.525924
# [480]	train-mlogloss:0.425874	test-mlogloss:0.525884
# [481]	train-mlogloss:0.42563	test-mlogloss:0.525847
# [482]	train-mlogloss:0.425421	test-mlogloss:0.525806
# [483]	train-mlogloss:0.425196	test-mlogloss:0.525767
# [484]	train-mlogloss:0.42503	test-mlogloss:0.525708
# [485]	train-mlogloss:0.42483	test-mlogloss:0.525664
# [486]	train-mlogloss:0.424611	test-mlogloss:0.525617
# [487]	train-mlogloss:0.424365	test-mlogloss:0.525615
# [488]	train-mlogloss:0.424216	test-mlogloss:0.525578
# [489]	train-mlogloss:0.42406	test-mlogloss:0.525544
# [490]	train-mlogloss:0.423832	test-mlogloss:0.525509
# [491]	train-mlogloss:0.423653	test-mlogloss:0.525484
# [492]	train-mlogloss:0.423498	test-mlogloss:0.525448
# [493]	train-mlogloss:0.42325	test-mlogloss:0.525381
# [494]	train-mlogloss:0.423031	test-mlogloss:0.525325
# [495]	train-mlogloss:0.422765	test-mlogloss:0.525283
# [496]	train-mlogloss:0.422586	test-mlogloss:0.525265
# [497]	train-mlogloss:0.422312	test-mlogloss:0.525216
# [498]	train-mlogloss:0.422035	test-mlogloss:0.525165
# [499]	train-mlogloss:0.421895	test-mlogloss:0.525151
# [500]	train-mlogloss:0.421633	test-mlogloss:0.525116
# [501]	train-mlogloss:0.421427	test-mlogloss:0.525062
# [502]	train-mlogloss:0.421159	test-mlogloss:0.525011
# [503]	train-mlogloss:0.421009	test-mlogloss:0.524965
# [504]	train-mlogloss:0.420834	test-mlogloss:0.524924
# [505]	train-mlogloss:0.42063	test-mlogloss:0.524911
# [506]	train-mlogloss:0.420445	test-mlogloss:0.524881
# [507]	train-mlogloss:0.420258	test-mlogloss:0.524869
# [508]	train-mlogloss:0.420045	test-mlogloss:0.524826
# [509]	train-mlogloss:0.4199	test-mlogloss:0.524797
# [510]	train-mlogloss:0.419717	test-mlogloss:0.524784
# [511]	train-mlogloss:0.419528	test-mlogloss:0.524751
# [512]	train-mlogloss:0.419341	test-mlogloss:0.524705
# [513]	train-mlogloss:0.41912	test-mlogloss:0.524692
# [514]	train-mlogloss:0.418916	test-mlogloss:0.524678
# [515]	train-mlogloss:0.418667	test-mlogloss:0.524637
# [516]	train-mlogloss:0.418482	test-mlogloss:0.52465
# [517]	train-mlogloss:0.418306	test-mlogloss:0.524596
# [518]	train-mlogloss:0.418079	test-mlogloss:0.524582
# [519]	train-mlogloss:0.417887	test-mlogloss:0.524511
# [520]	train-mlogloss:0.41767	test-mlogloss:0.524519
# [521]	train-mlogloss:0.417499	test-mlogloss:0.524447
# [522]	train-mlogloss:0.417355	test-mlogloss:0.524389
# [523]	train-mlogloss:0.417128	test-mlogloss:0.524357
# [524]	train-mlogloss:0.416936	test-mlogloss:0.524331
# [525]	train-mlogloss:0.41675	test-mlogloss:0.524283
# [526]	train-mlogloss:0.416566	test-mlogloss:0.524255
# [527]	train-mlogloss:0.416351	test-mlogloss:0.5242
# [528]	train-mlogloss:0.416171	test-mlogloss:0.524138
# [529]	train-mlogloss:0.416036	test-mlogloss:0.524142
# [530]	train-mlogloss:0.415825	test-mlogloss:0.524117
# [531]	train-mlogloss:0.415626	test-mlogloss:0.524073
# [532]	train-mlogloss:0.415448	test-mlogloss:0.524047
# [533]	train-mlogloss:0.415281	test-mlogloss:0.52402
# [534]	train-mlogloss:0.415112	test-mlogloss:0.523999
# [535]	train-mlogloss:0.414905	test-mlogloss:0.523957
# [536]	train-mlogloss:0.414696	test-mlogloss:0.523924
# [537]	train-mlogloss:0.414484	test-mlogloss:0.523886
# [538]	train-mlogloss:0.414286	test-mlogloss:0.523856
# [539]	train-mlogloss:0.414096	test-mlogloss:0.523846
# [540]	train-mlogloss:0.413899	test-mlogloss:0.523798
# [541]	train-mlogloss:0.413711	test-mlogloss:0.523725
# [542]	train-mlogloss:0.413476	test-mlogloss:0.523703
# [543]	train-mlogloss:0.413287	test-mlogloss:0.52366
# [544]	train-mlogloss:0.41315	test-mlogloss:0.523614
# [545]	train-mlogloss:0.412963	test-mlogloss:0.523607
# [546]	train-mlogloss:0.412772	test-mlogloss:0.523583
# [547]	train-mlogloss:0.412574	test-mlogloss:0.52356
# [548]	train-mlogloss:0.412426	test-mlogloss:0.523512
# [549]	train-mlogloss:0.41222	test-mlogloss:0.523473
# [550]	train-mlogloss:0.412123	test-mlogloss:0.52345
# [551]	train-mlogloss:0.411916	test-mlogloss:0.523403
# [552]	train-mlogloss:0.411784	test-mlogloss:0.52338
# [553]	train-mlogloss:0.411583	test-mlogloss:0.523303
# [554]	train-mlogloss:0.411407	test-mlogloss:0.523281
# [555]	train-mlogloss:0.411192	test-mlogloss:0.523243
# [556]	train-mlogloss:0.410939	test-mlogloss:0.523207
# [557]	train-mlogloss:0.4108	test-mlogloss:0.523166
# [558]	train-mlogloss:0.410618	test-mlogloss:0.523122
# [559]	train-mlogloss:0.410466	test-mlogloss:0.523121
# [560]	train-mlogloss:0.410246	test-mlogloss:0.523068
# [561]	train-mlogloss:0.410085	test-mlogloss:0.523046
# [562]	train-mlogloss:0.409861	test-mlogloss:0.522979
# [563]	train-mlogloss:0.409693	test-mlogloss:0.522939
# [564]	train-mlogloss:0.409554	test-mlogloss:0.522901
# [565]	train-mlogloss:0.409354	test-mlogloss:0.522867
# [566]	train-mlogloss:0.409101	test-mlogloss:0.522818
# [567]	train-mlogloss:0.408981	test-mlogloss:0.522793
# [568]	train-mlogloss:0.408816	test-mlogloss:0.522769
# [569]	train-mlogloss:0.40862	test-mlogloss:0.522754
# [570]	train-mlogloss:0.408479	test-mlogloss:0.522737
# [571]	train-mlogloss:0.408355	test-mlogloss:0.522709
# [572]	train-mlogloss:0.408233	test-mlogloss:0.522704
# [573]	train-mlogloss:0.408037	test-mlogloss:0.522693
# [574]	train-mlogloss:0.407886	test-mlogloss:0.522666
# [575]	train-mlogloss:0.407679	test-mlogloss:0.522638
# [576]	train-mlogloss:0.407514	test-mlogloss:0.522594
# [577]	train-mlogloss:0.407285	test-mlogloss:0.522587
# [578]	train-mlogloss:0.407149	test-mlogloss:0.522541
# [579]	train-mlogloss:0.406968	test-mlogloss:0.522515
# [580]	train-mlogloss:0.406743	test-mlogloss:0.52245
# [581]	train-mlogloss:0.406604	test-mlogloss:0.522415
# [582]	train-mlogloss:0.406389	test-mlogloss:0.522361
# [583]	train-mlogloss:0.406191	test-mlogloss:0.522318
# [584]	train-mlogloss:0.405987	test-mlogloss:0.522281
# [585]	train-mlogloss:0.405797	test-mlogloss:0.522249
# [586]	train-mlogloss:0.405619	test-mlogloss:0.522233
# [587]	train-mlogloss:0.405445	test-mlogloss:0.522219
# [588]	train-mlogloss:0.405252	test-mlogloss:0.522164
# [589]	train-mlogloss:0.405091	test-mlogloss:0.522127
# [590]	train-mlogloss:0.404911	test-mlogloss:0.522129
# [591]	train-mlogloss:0.404735	test-mlogloss:0.522106
# [592]	train-mlogloss:0.404624	test-mlogloss:0.522075
# [593]	train-mlogloss:0.404464	test-mlogloss:0.522043
# [594]	train-mlogloss:0.404283	test-mlogloss:0.522025
# [595]	train-mlogloss:0.404079	test-mlogloss:0.52197
# [596]	train-mlogloss:0.403872	test-mlogloss:0.521961
# [597]	train-mlogloss:0.40369	test-mlogloss:0.521924
# [598]	train-mlogloss:0.403531	test-mlogloss:0.521899
# [599]	train-mlogloss:0.403323	test-mlogloss:0.521876
# [600]	train-mlogloss:0.403124	test-mlogloss:0.521858
# [601]	train-mlogloss:0.403015	test-mlogloss:0.521843
# [602]	train-mlogloss:0.402873	test-mlogloss:0.521805
# [603]	train-mlogloss:0.402701	test-mlogloss:0.521762
# [604]	train-mlogloss:0.402479	test-mlogloss:0.521742
# [605]	train-mlogloss:0.402321	test-mlogloss:0.521721
# [606]	train-mlogloss:0.402213	test-mlogloss:0.521687
# [607]	train-mlogloss:0.402	test-mlogloss:0.52163
# [608]	train-mlogloss:0.401849	test-mlogloss:0.521652
# [609]	train-mlogloss:0.401707	test-mlogloss:0.521654
# [610]	train-mlogloss:0.401532	test-mlogloss:0.52162
# [611]	train-mlogloss:0.401272	test-mlogloss:0.521567
# [612]	train-mlogloss:0.401122	test-mlogloss:0.521528
# [613]	train-mlogloss:0.400972	test-mlogloss:0.521506
# [614]	train-mlogloss:0.400803	test-mlogloss:0.521454
# [615]	train-mlogloss:0.400565	test-mlogloss:0.521442
# [616]	train-mlogloss:0.400448	test-mlogloss:0.521402
# [617]	train-mlogloss:0.400277	test-mlogloss:0.521387
# [618]	train-mlogloss:0.400028	test-mlogloss:0.521358
# [619]	train-mlogloss:0.399844	test-mlogloss:0.521344
# [620]	train-mlogloss:0.399694	test-mlogloss:0.521298
# [621]	train-mlogloss:0.399479	test-mlogloss:0.521261
# [622]	train-mlogloss:0.39928	test-mlogloss:0.521233
# [623]	train-mlogloss:0.399044	test-mlogloss:0.521187
# [624]	train-mlogloss:0.398849	test-mlogloss:0.521153
# [625]	train-mlogloss:0.398737	test-mlogloss:0.521167
# [626]	train-mlogloss:0.398605	test-mlogloss:0.521159
# [627]	train-mlogloss:0.398432	test-mlogloss:0.52115
# [628]	train-mlogloss:0.398238	test-mlogloss:0.521131
# [629]	train-mlogloss:0.398079	test-mlogloss:0.521095
# [630]	train-mlogloss:0.397915	test-mlogloss:0.521047
# [631]	train-mlogloss:0.397748	test-mlogloss:0.52104
# [632]	train-mlogloss:0.397547	test-mlogloss:0.521042
# [633]	train-mlogloss:0.397409	test-mlogloss:0.520999
# [634]	train-mlogloss:0.39725	test-mlogloss:0.520957
# [635]	train-mlogloss:0.397079	test-mlogloss:0.520935
# [636]	train-mlogloss:0.396917	test-mlogloss:0.520896
# [637]	train-mlogloss:0.396683	test-mlogloss:0.520851
# [638]	train-mlogloss:0.396569	test-mlogloss:0.520806
# [639]	train-mlogloss:0.396339	test-mlogloss:0.520798
# [640]	train-mlogloss:0.396122	test-mlogloss:0.520795
# [641]	train-mlogloss:0.395858	test-mlogloss:0.520734
# [642]	train-mlogloss:0.395675	test-mlogloss:0.520713
# [643]	train-mlogloss:0.395459	test-mlogloss:0.52071
# [644]	train-mlogloss:0.395274	test-mlogloss:0.520668
# [645]	train-mlogloss:0.395112	test-mlogloss:0.520648
# [646]	train-mlogloss:0.394943	test-mlogloss:0.520622
# [647]	train-mlogloss:0.394796	test-mlogloss:0.520607
# [648]	train-mlogloss:0.394615	test-mlogloss:0.520591
# [649]	train-mlogloss:0.394455	test-mlogloss:0.520578
# [650]	train-mlogloss:0.394291	test-mlogloss:0.520549
# [651]	train-mlogloss:0.394123	test-mlogloss:0.52051
# [652]	train-mlogloss:0.393899	test-mlogloss:0.520468
# [653]	train-mlogloss:0.393724	test-mlogloss:0.520454
# [654]	train-mlogloss:0.393557	test-mlogloss:0.520443
# [655]	train-mlogloss:0.39338	test-mlogloss:0.520423
# [656]	train-mlogloss:0.393165	test-mlogloss:0.520394
# [657]	train-mlogloss:0.393002	test-mlogloss:0.520353
# [658]	train-mlogloss:0.392843	test-mlogloss:0.520338
# [659]	train-mlogloss:0.392693	test-mlogloss:0.520299
# [660]	train-mlogloss:0.392517	test-mlogloss:0.520253
# [661]	train-mlogloss:0.39236	test-mlogloss:0.520201
# [662]	train-mlogloss:0.392246	test-mlogloss:0.520181
# [663]	train-mlogloss:0.392137	test-mlogloss:0.520152
# [664]	train-mlogloss:0.392008	test-mlogloss:0.520126
# [665]	train-mlogloss:0.391825	test-mlogloss:0.520121
# [666]	train-mlogloss:0.391597	test-mlogloss:0.520093
# [667]	train-mlogloss:0.391423	test-mlogloss:0.52009
# [668]	train-mlogloss:0.391242	test-mlogloss:0.520111
# [669]	train-mlogloss:0.391112	test-mlogloss:0.520075
# [670]	train-mlogloss:0.390944	test-mlogloss:0.520023
# [671]	train-mlogloss:0.390806	test-mlogloss:0.520022
# [672]	train-mlogloss:0.390606	test-mlogloss:0.519994
# [673]	train-mlogloss:0.390461	test-mlogloss:0.519985
# [674]	train-mlogloss:0.390334	test-mlogloss:0.519976
# [675]	train-mlogloss:0.390221	test-mlogloss:0.519947
# [676]	train-mlogloss:0.390094	test-mlogloss:0.519927
# [677]	train-mlogloss:0.389928	test-mlogloss:0.519893
# [678]	train-mlogloss:0.389785	test-mlogloss:0.519885
# [679]	train-mlogloss:0.389633	test-mlogloss:0.519899
# [680]	train-mlogloss:0.389478	test-mlogloss:0.519884
# [681]	train-mlogloss:0.389376	test-mlogloss:0.519841
# [682]	train-mlogloss:0.389218	test-mlogloss:0.519808
# [683]	train-mlogloss:0.389033	test-mlogloss:0.519771
# [684]	train-mlogloss:0.388844	test-mlogloss:0.519722
# [685]	train-mlogloss:0.388693	test-mlogloss:0.519702
# [686]	train-mlogloss:0.388563	test-mlogloss:0.519683
# [687]	train-mlogloss:0.388346	test-mlogloss:0.51966
# [688]	train-mlogloss:0.388164	test-mlogloss:0.519633
# [689]	train-mlogloss:0.387953	test-mlogloss:0.519603
# [690]	train-mlogloss:0.38774	test-mlogloss:0.519585
# [691]	train-mlogloss:0.387583	test-mlogloss:0.519554
# [692]	train-mlogloss:0.387391	test-mlogloss:0.519541
# [693]	train-mlogloss:0.387258	test-mlogloss:0.519506
# [694]	train-mlogloss:0.387069	test-mlogloss:0.519495
# [695]	train-mlogloss:0.386968	test-mlogloss:0.519508
# [696]	train-mlogloss:0.386819	test-mlogloss:0.519521
# [697]	train-mlogloss:0.38666	test-mlogloss:0.519524
# [698]	train-mlogloss:0.386484	test-mlogloss:0.519535
# [699]	train-mlogloss:0.386326	test-mlogloss:0.519511
# [700]	train-mlogloss:0.386139	test-mlogloss:0.519493
# [701]	train-mlogloss:0.385947	test-mlogloss:0.519473
# [702]	train-mlogloss:0.385816	test-mlogloss:0.519465
# [703]	train-mlogloss:0.385731	test-mlogloss:0.51944
# [704]	train-mlogloss:0.385593	test-mlogloss:0.519412
# [705]	train-mlogloss:0.38545	test-mlogloss:0.519417
# [706]	train-mlogloss:0.38529	test-mlogloss:0.519392
# [707]	train-mlogloss:0.385115	test-mlogloss:0.519372
# [708]	train-mlogloss:0.384996	test-mlogloss:0.519357
# [709]	train-mlogloss:0.384827	test-mlogloss:0.519325
# [710]	train-mlogloss:0.384618	test-mlogloss:0.51932
# [711]	train-mlogloss:0.384421	test-mlogloss:0.519298
# [712]	train-mlogloss:0.384281	test-mlogloss:0.519282
# [713]	train-mlogloss:0.384091	test-mlogloss:0.519287
# [714]	train-mlogloss:0.383945	test-mlogloss:0.519266
# [715]	train-mlogloss:0.383796	test-mlogloss:0.519231
# [716]	train-mlogloss:0.38361	test-mlogloss:0.519217
# [717]	train-mlogloss:0.383407	test-mlogloss:0.519215
# [718]	train-mlogloss:0.383252	test-mlogloss:0.519212
# [719]	train-mlogloss:0.383125	test-mlogloss:0.519193
# [720]	train-mlogloss:0.382926	test-mlogloss:0.519161
# [721]	train-mlogloss:0.382755	test-mlogloss:0.519163
# [722]	train-mlogloss:0.382606	test-mlogloss:0.519122
# [723]	train-mlogloss:0.382429	test-mlogloss:0.519108
# [724]	train-mlogloss:0.38229	test-mlogloss:0.51909
# [725]	train-mlogloss:0.382107	test-mlogloss:0.519086
# [726]	train-mlogloss:0.381941	test-mlogloss:0.519057
# [727]	train-mlogloss:0.381824	test-mlogloss:0.519074
# [728]	train-mlogloss:0.381699	test-mlogloss:0.519067
# [729]	train-mlogloss:0.381543	test-mlogloss:0.519055
# [730]	train-mlogloss:0.381414	test-mlogloss:0.519052
# [731]	train-mlogloss:0.381241	test-mlogloss:0.519044
# [732]	train-mlogloss:0.381084	test-mlogloss:0.519022
# [733]	train-mlogloss:0.380904	test-mlogloss:0.518994
# [734]	train-mlogloss:0.380742	test-mlogloss:0.51896
# [735]	train-mlogloss:0.38062	test-mlogloss:0.518928
# [736]	train-mlogloss:0.380498	test-mlogloss:0.5189
# [737]	train-mlogloss:0.380344	test-mlogloss:0.518903
# [738]	train-mlogloss:0.380179	test-mlogloss:0.518897
# [739]	train-mlogloss:0.380037	test-mlogloss:0.518888
# [740]	train-mlogloss:0.379932	test-mlogloss:0.518886
# [741]	train-mlogloss:0.379765	test-mlogloss:0.518865
# [742]	train-mlogloss:0.379584	test-mlogloss:0.51887
# [743]	train-mlogloss:0.379457	test-mlogloss:0.518854
# [744]	train-mlogloss:0.379293	test-mlogloss:0.51882
# [745]	train-mlogloss:0.379175	test-mlogloss:0.518812
# [746]	train-mlogloss:0.379037	test-mlogloss:0.518782
# [747]	train-mlogloss:0.378853	test-mlogloss:0.518766
# [748]	train-mlogloss:0.378694	test-mlogloss:0.518746
# [749]	train-mlogloss:0.378485	test-mlogloss:0.518757
# [750]	train-mlogloss:0.378292	test-mlogloss:0.518763
# [751]	train-mlogloss:0.378135	test-mlogloss:0.51875
# [752]	train-mlogloss:0.377961	test-mlogloss:0.518708
# [753]	train-mlogloss:0.377853	test-mlogloss:0.51869
# [754]	train-mlogloss:0.377751	test-mlogloss:0.518682
# [755]	train-mlogloss:0.377603	test-mlogloss:0.518665
# [756]	train-mlogloss:0.377432	test-mlogloss:0.518615
# [757]	train-mlogloss:0.377202	test-mlogloss:0.518628
# [758]	train-mlogloss:0.376993	test-mlogloss:0.518595
# [759]	train-mlogloss:0.376837	test-mlogloss:0.518569
# [760]	train-mlogloss:0.376707	test-mlogloss:0.518553
# [761]	train-mlogloss:0.376543	test-mlogloss:0.518533
# [762]	train-mlogloss:0.37638	test-mlogloss:0.518505
# [763]	train-mlogloss:0.376214	test-mlogloss:0.518529
# [764]	train-mlogloss:0.376006	test-mlogloss:0.518524
# [765]	train-mlogloss:0.375823	test-mlogloss:0.518515
# [766]	train-mlogloss:0.375664	test-mlogloss:0.518522
# [767]	train-mlogloss:0.375551	test-mlogloss:0.518503
# [768]	train-mlogloss:0.375389	test-mlogloss:0.518486
# [769]	train-mlogloss:0.37519	test-mlogloss:0.518501
# [770]	train-mlogloss:0.375073	test-mlogloss:0.5185
# [771]	train-mlogloss:0.374856	test-mlogloss:0.518472
# [772]	train-mlogloss:0.37469	test-mlogloss:0.518463
# [773]	train-mlogloss:0.374582	test-mlogloss:0.518424
# [774]	train-mlogloss:0.374435	test-mlogloss:0.518421
# [775]	train-mlogloss:0.374309	test-mlogloss:0.51843
# [776]	train-mlogloss:0.374189	test-mlogloss:0.518404
# [777]	train-mlogloss:0.374039	test-mlogloss:0.518403
# [778]	train-mlogloss:0.373863	test-mlogloss:0.518378
# [779]	train-mlogloss:0.373752	test-mlogloss:0.518373
# [780]	train-mlogloss:0.373612	test-mlogloss:0.518332
# [781]	train-mlogloss:0.373496	test-mlogloss:0.518311
# [782]	train-mlogloss:0.373374	test-mlogloss:0.518316
# [783]	train-mlogloss:0.373172	test-mlogloss:0.518296
# [784]	train-mlogloss:0.373014	test-mlogloss:0.518298
# [785]	train-mlogloss:0.372822	test-mlogloss:0.51832
# [786]	train-mlogloss:0.372666	test-mlogloss:0.518321
# [787]	train-mlogloss:0.372461	test-mlogloss:0.518285
# [788]	train-mlogloss:0.37231	test-mlogloss:0.518282
# [789]	train-mlogloss:0.372128	test-mlogloss:0.518289
# [790]	train-mlogloss:0.371949	test-mlogloss:0.518274
# [791]	train-mlogloss:0.371847	test-mlogloss:0.518259
# [792]	train-mlogloss:0.371752	test-mlogloss:0.518242
# [793]	train-mlogloss:0.371589	test-mlogloss:0.518227
# [794]	train-mlogloss:0.371422	test-mlogloss:0.518232
# [795]	train-mlogloss:0.371224	test-mlogloss:0.5182
# [796]	train-mlogloss:0.371027	test-mlogloss:0.51817
# [797]	train-mlogloss:0.370858	test-mlogloss:0.518189
# [798]	train-mlogloss:0.370699	test-mlogloss:0.518197
# [799]	train-mlogloss:0.370498	test-mlogloss:0.518176
# [800]	train-mlogloss:0.370324	test-mlogloss:0.518161
# [801]	train-mlogloss:0.37008	test-mlogloss:0.518154
# [802]	train-mlogloss:0.369967	test-mlogloss:0.51813
# [803]	train-mlogloss:0.369776	test-mlogloss:0.51813
# [804]	train-mlogloss:0.369633	test-mlogloss:0.518114
# [805]	train-mlogloss:0.369489	test-mlogloss:0.518099
# [806]	train-mlogloss:0.369335	test-mlogloss:0.518094
# [807]	train-mlogloss:0.369183	test-mlogloss:0.518081
# [808]	train-mlogloss:0.369027	test-mlogloss:0.518064
# [809]	train-mlogloss:0.368898	test-mlogloss:0.518051
# [810]	train-mlogloss:0.368795	test-mlogloss:0.518041
# [811]	train-mlogloss:0.368642	test-mlogloss:0.518025
# [812]	train-mlogloss:0.368439	test-mlogloss:0.518016
# [813]	train-mlogloss:0.36833	test-mlogloss:0.518013
# [814]	train-mlogloss:0.36814	test-mlogloss:0.518019
# [815]	train-mlogloss:0.367976	test-mlogloss:0.518002
# [816]	train-mlogloss:0.367823	test-mlogloss:0.517983
# [817]	train-mlogloss:0.367607	test-mlogloss:0.517978
# [818]	train-mlogloss:0.367439	test-mlogloss:0.517982
# [819]	train-mlogloss:0.367312	test-mlogloss:0.517954
# [820]	train-mlogloss:0.36719	test-mlogloss:0.517949
# [821]	train-mlogloss:0.367062	test-mlogloss:0.517928
# [822]	train-mlogloss:0.366883	test-mlogloss:0.517935
# [823]	train-mlogloss:0.36678	test-mlogloss:0.517945
# [824]	train-mlogloss:0.36666	test-mlogloss:0.517937
# [825]	train-mlogloss:0.366506	test-mlogloss:0.517934
# [826]	train-mlogloss:0.36639	test-mlogloss:0.51794
# [827]	train-mlogloss:0.366251	test-mlogloss:0.517923
# [828]	train-mlogloss:0.366084	test-mlogloss:0.517903
# [829]	train-mlogloss:0.36595	test-mlogloss:0.517861
# [830]	train-mlogloss:0.365809	test-mlogloss:0.517868
# [831]	train-mlogloss:0.365681	test-mlogloss:0.517835
# [832]	train-mlogloss:0.36554	test-mlogloss:0.517819
# [833]	train-mlogloss:0.365436	test-mlogloss:0.517808
# [834]	train-mlogloss:0.365261	test-mlogloss:0.517774
# [835]	train-mlogloss:0.365136	test-mlogloss:0.517807
# [836]	train-mlogloss:0.364988	test-mlogloss:0.517783
# [837]	train-mlogloss:0.364812	test-mlogloss:0.517762
# [838]	train-mlogloss:0.364667	test-mlogloss:0.517741
# [839]	train-mlogloss:0.364524	test-mlogloss:0.517715
# [840]	train-mlogloss:0.364383	test-mlogloss:0.517698
# [841]	train-mlogloss:0.364261	test-mlogloss:0.517671
# [842]	train-mlogloss:0.364089	test-mlogloss:0.517658
# [843]	train-mlogloss:0.363986	test-mlogloss:0.517654
# [844]	train-mlogloss:0.363821	test-mlogloss:0.517639
# [845]	train-mlogloss:0.363716	test-mlogloss:0.517651
# [846]	train-mlogloss:0.363573	test-mlogloss:0.517654
# [847]	train-mlogloss:0.36341	test-mlogloss:0.517625
# [848]	train-mlogloss:0.363219	test-mlogloss:0.5176
# [849]	train-mlogloss:0.363119	test-mlogloss:0.517604
# [850]	train-mlogloss:0.363002	test-mlogloss:0.517611
# [851]	train-mlogloss:0.362813	test-mlogloss:0.517575
# [852]	train-mlogloss:0.362656	test-mlogloss:0.517565
# [853]	train-mlogloss:0.362497	test-mlogloss:0.51754
# [854]	train-mlogloss:0.362342	test-mlogloss:0.517534
# [855]	train-mlogloss:0.362198	test-mlogloss:0.517516
# [856]	train-mlogloss:0.362047	test-mlogloss:0.517503
# [857]	train-mlogloss:0.361884	test-mlogloss:0.517506
# [858]	train-mlogloss:0.36177	test-mlogloss:0.517486
# [859]	train-mlogloss:0.361623	test-mlogloss:0.517474
# [860]	train-mlogloss:0.361482	test-mlogloss:0.51742
# [861]	train-mlogloss:0.361343	test-mlogloss:0.517421
# [862]	train-mlogloss:0.36123	test-mlogloss:0.517395
# [863]	train-mlogloss:0.36104	test-mlogloss:0.517359
# [864]	train-mlogloss:0.360944	test-mlogloss:0.517349
# [865]	train-mlogloss:0.360808	test-mlogloss:0.517367
# [866]	train-mlogloss:0.360666	test-mlogloss:0.517338
# [867]	train-mlogloss:0.360497	test-mlogloss:0.517308
# [868]	train-mlogloss:0.360341	test-mlogloss:0.517295
# [869]	train-mlogloss:0.360218	test-mlogloss:0.517283
# [870]	train-mlogloss:0.360068	test-mlogloss:0.517272
# [871]	train-mlogloss:0.359918	test-mlogloss:0.517241
# [872]	train-mlogloss:0.359769	test-mlogloss:0.517235
# [873]	train-mlogloss:0.359675	test-mlogloss:0.517231
# [874]	train-mlogloss:0.359543	test-mlogloss:0.517232
# [875]	train-mlogloss:0.359388	test-mlogloss:0.517201
# [876]	train-mlogloss:0.359221	test-mlogloss:0.517173
# [877]	train-mlogloss:0.359065	test-mlogloss:0.517136
# [878]	train-mlogloss:0.358901	test-mlogloss:0.51712
# [879]	train-mlogloss:0.358769	test-mlogloss:0.517099
# [880]	train-mlogloss:0.358649	test-mlogloss:0.517082
# [881]	train-mlogloss:0.358483	test-mlogloss:0.517091
# [882]	train-mlogloss:0.358299	test-mlogloss:0.517105
# [883]	train-mlogloss:0.358173	test-mlogloss:0.517101
# [884]	train-mlogloss:0.358082	test-mlogloss:0.517079
# [885]	train-mlogloss:0.357946	test-mlogloss:0.517028
# [886]	train-mlogloss:0.357795	test-mlogloss:0.517023
# [887]	train-mlogloss:0.357661	test-mlogloss:0.516996
# [888]	train-mlogloss:0.357481	test-mlogloss:0.516988
# [889]	train-mlogloss:0.357392	test-mlogloss:0.516985
# [890]	train-mlogloss:0.357225	test-mlogloss:0.516986
# [891]	train-mlogloss:0.35709	test-mlogloss:0.51699
# [892]	train-mlogloss:0.356988	test-mlogloss:0.516963
# [893]	train-mlogloss:0.356867	test-mlogloss:0.516963
# [894]	train-mlogloss:0.35672	test-mlogloss:0.516962
# [895]	train-mlogloss:0.35651	test-mlogloss:0.516938
# [896]	train-mlogloss:0.356384	test-mlogloss:0.516922
# [897]	train-mlogloss:0.356211	test-mlogloss:0.516913
# [898]	train-mlogloss:0.356084	test-mlogloss:0.516908
# [899]	train-mlogloss:0.355935	test-mlogloss:0.516863
# [900]	train-mlogloss:0.355783	test-mlogloss:0.516879
# [901]	train-mlogloss:0.355606	test-mlogloss:0.516892
# [902]	train-mlogloss:0.355457	test-mlogloss:0.516882
# [903]	train-mlogloss:0.355322	test-mlogloss:0.516865
# [904]	train-mlogloss:0.355145	test-mlogloss:0.516849
# [905]	train-mlogloss:0.355008	test-mlogloss:0.516849
# [906]	train-mlogloss:0.354849	test-mlogloss:0.516846
# [907]	train-mlogloss:0.354717	test-mlogloss:0.516826
# [908]	train-mlogloss:0.354553	test-mlogloss:0.516824
# [909]	train-mlogloss:0.354428	test-mlogloss:0.51681
# [910]	train-mlogloss:0.354295	test-mlogloss:0.516795
# [911]	train-mlogloss:0.35416	test-mlogloss:0.516789
# [912]	train-mlogloss:0.354069	test-mlogloss:0.516761
# [913]	train-mlogloss:0.353904	test-mlogloss:0.516748
# [914]	train-mlogloss:0.353793	test-mlogloss:0.51675
# [915]	train-mlogloss:0.353671	test-mlogloss:0.516753
# [916]	train-mlogloss:0.353494	test-mlogloss:0.516736
# [917]	train-mlogloss:0.353359	test-mlogloss:0.516742
# [918]	train-mlogloss:0.353183	test-mlogloss:0.516732
# [919]	train-mlogloss:0.353063	test-mlogloss:0.516706
# [920]	train-mlogloss:0.352896	test-mlogloss:0.516709
# [921]	train-mlogloss:0.352737	test-mlogloss:0.516712
# [922]	train-mlogloss:0.352604	test-mlogloss:0.516718
# [923]	train-mlogloss:0.352418	test-mlogloss:0.516679
# [924]	train-mlogloss:0.352306	test-mlogloss:0.516672
# [925]	train-mlogloss:0.352172	test-mlogloss:0.516672
# [926]	train-mlogloss:0.351975	test-mlogloss:0.516639
# [927]	train-mlogloss:0.351866	test-mlogloss:0.516649
# [928]	train-mlogloss:0.351721	test-mlogloss:0.516653
# [929]	train-mlogloss:0.351565	test-mlogloss:0.516657
# [930]	train-mlogloss:0.351416	test-mlogloss:0.516671
# [931]	train-mlogloss:0.351293	test-mlogloss:0.516658
# [932]	train-mlogloss:0.351147	test-mlogloss:0.51663
# [933]	train-mlogloss:0.351059	test-mlogloss:0.516638
# [934]	train-mlogloss:0.350936	test-mlogloss:0.516625
# [935]	train-mlogloss:0.350797	test-mlogloss:0.516591
# [936]	train-mlogloss:0.35065	test-mlogloss:0.516574
# [937]	train-mlogloss:0.350484	test-mlogloss:0.516575
# [938]	train-mlogloss:0.350363	test-mlogloss:0.516568
# [939]	train-mlogloss:0.350208	test-mlogloss:0.516539
# [940]	train-mlogloss:0.350046	test-mlogloss:0.516523
# [941]	train-mlogloss:0.349921	test-mlogloss:0.516514
# [942]	train-mlogloss:0.349806	test-mlogloss:0.516517
# [943]	train-mlogloss:0.349673	test-mlogloss:0.516523
# [944]	train-mlogloss:0.3496	test-mlogloss:0.516524
# [945]	train-mlogloss:0.349484	test-mlogloss:0.516504
# [946]	train-mlogloss:0.349361	test-mlogloss:0.516478
# [947]	train-mlogloss:0.34925	test-mlogloss:0.516466
# [948]	train-mlogloss:0.34911	test-mlogloss:0.516454
# [949]	train-mlogloss:0.348963	test-mlogloss:0.516448
# [950]	train-mlogloss:0.348799	test-mlogloss:0.516434
# [951]	train-mlogloss:0.348676	test-mlogloss:0.516388
# [952]	train-mlogloss:0.348543	test-mlogloss:0.516395
# [953]	train-mlogloss:0.348372	test-mlogloss:0.516394
# [954]	train-mlogloss:0.348254	test-mlogloss:0.516395
# [955]	train-mlogloss:0.348112	test-mlogloss:0.516357
# [956]	train-mlogloss:0.347953	test-mlogloss:0.51634
# [957]	train-mlogloss:0.347787	test-mlogloss:0.516317
# [958]	train-mlogloss:0.347664	test-mlogloss:0.516323
# [959]	train-mlogloss:0.34752	test-mlogloss:0.516318
# [960]	train-mlogloss:0.347381	test-mlogloss:0.516315
# [961]	train-mlogloss:0.347236	test-mlogloss:0.516298
# [962]	train-mlogloss:0.347122	test-mlogloss:0.516298
# [963]	train-mlogloss:0.346986	test-mlogloss:0.516309
# [964]	train-mlogloss:0.346911	test-mlogloss:0.516306
# [965]	train-mlogloss:0.346842	test-mlogloss:0.516312
# [966]	train-mlogloss:0.346718	test-mlogloss:0.516325
# [967]	train-mlogloss:0.346552	test-mlogloss:0.516315
# [968]	train-mlogloss:0.346433	test-mlogloss:0.516319
# [969]	train-mlogloss:0.346284	test-mlogloss:0.516346
# [970]	train-mlogloss:0.346162	test-mlogloss:0.516319
# [971]	train-mlogloss:0.346034	test-mlogloss:0.51628
# [972]	train-mlogloss:0.345932	test-mlogloss:0.516272
# [973]	train-mlogloss:0.345808	test-mlogloss:0.516279
# [974]	train-mlogloss:0.345681	test-mlogloss:0.516259
# [975]	train-mlogloss:0.345563	test-mlogloss:0.516269
# [976]	train-mlogloss:0.345439	test-mlogloss:0.516244
# [977]	train-mlogloss:0.34527	test-mlogloss:0.516231
# [978]	train-mlogloss:0.345142	test-mlogloss:0.51621
# [979]	train-mlogloss:0.34508	test-mlogloss:0.516203
# [980]	train-mlogloss:0.34492	test-mlogloss:0.516173
# [981]	train-mlogloss:0.344791	test-mlogloss:0.516177
# [982]	train-mlogloss:0.344665	test-mlogloss:0.516189
# [983]	train-mlogloss:0.344516	test-mlogloss:0.516196
# [984]	train-mlogloss:0.344356	test-mlogloss:0.516172
# [985]	train-mlogloss:0.344211	test-mlogloss:0.516153
# [986]	train-mlogloss:0.344072	test-mlogloss:0.516162
# [987]	train-mlogloss:0.343989	test-mlogloss:0.51617
# [988]	train-mlogloss:0.343849	test-mlogloss:0.516163
# [989]	train-mlogloss:0.343738	test-mlogloss:0.51619
# [990]	train-mlogloss:0.343566	test-mlogloss:0.516197
# [991]	train-mlogloss:0.34342	test-mlogloss:0.516209
# [992]	train-mlogloss:0.34326	test-mlogloss:0.516208
# [993]	train-mlogloss:0.343105	test-mlogloss:0.516183
# [994]	train-mlogloss:0.342949	test-mlogloss:0.516186
# [995]	train-mlogloss:0.342809	test-mlogloss:0.516189
# [996]	train-mlogloss:0.342681	test-mlogloss:0.516182
# [997]	train-mlogloss:0.342558	test-mlogloss:0.516167
# [998]	train-mlogloss:0.342423	test-mlogloss:0.516167
# [999]	train-mlogloss:0.342275	test-mlogloss:0.516152
# [1000]	train-mlogloss:0.342167	test-mlogloss:0.51613
# [1001]	train-mlogloss:0.34201	test-mlogloss:0.516121
# [1002]	train-mlogloss:0.341877	test-mlogloss:0.516139
# [1003]	train-mlogloss:0.341736	test-mlogloss:0.516136
# [1004]	train-mlogloss:0.341572	test-mlogloss:0.516143
# [1005]	train-mlogloss:0.341441	test-mlogloss:0.516166
# [1006]	train-mlogloss:0.341318	test-mlogloss:0.516194
# [1007]	train-mlogloss:0.34121	test-mlogloss:0.516189
# [1008]	train-mlogloss:0.341082	test-mlogloss:0.516181
# [1009]	train-mlogloss:0.340951	test-mlogloss:0.516162
# [1010]	train-mlogloss:0.340821	test-mlogloss:0.516163
# [1011]	train-mlogloss:0.340672	test-mlogloss:0.516186
# [1012]	train-mlogloss:0.340567	test-mlogloss:0.516187
# [1013]	train-mlogloss:0.340393	test-mlogloss:0.5162
# [1014]	train-mlogloss:0.340279	test-mlogloss:0.516235
# [1015]	train-mlogloss:0.340158	test-mlogloss:0.516219
# [1016]	train-mlogloss:0.340068	test-mlogloss:0.516234
# [1017]	train-mlogloss:0.339952	test-mlogloss:0.516248
# [1018]	train-mlogloss:0.339836	test-mlogloss:0.516244
# [1019]	train-mlogloss:0.339733	test-mlogloss:0.516232
# [1020]	train-mlogloss:0.339583	test-mlogloss:0.516227
# [1021]	train-mlogloss:0.339403	test-mlogloss:0.516243
# Stopping. Best iteration:
# [1001]	train-mlogloss:0.34201	test-mlogloss:0.516121
#
# [0.51624292522854143]

# %%
preds, model = runXGB(train_X, train_y, test_X, num_rounds=1800)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
#out_df["listing_id"]=out_df["listing_id"]+68119576.0
out_df.to_csv("best_single_model_sent_nofeatdistance_new_0425.csv", index=False)
